# %% [markdown]
# <a href="https://colab.research.google.com/github/nouha18/pythoncheckpoint/blob/update/Dataset_house_Regression_v2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pand
import numpy as np

dataframe= pand.read_csv('./housedata.csv')
dataframe
# Out:
#                id             date  ...  sqft_living15  sqft_lot15
# 0      7129300520  20141013T000000  ...           1340        5650
# 1      6414100192  20141209T000000  ...           1690        7639
# 2      5631500400  20150225T000000  ...           2720        8062
# 3      2487200875  20141209T000000  ...           1360        5000
# 4      1954400510  20150218T000000  ...           1800        7503
# ...           ...              ...  ...            ...         ...
# 21608   263000018  20140521T000000  ...           1530        1509
# 21609  6600060120  20150223T000000  ...           1830        7200
# 21610  1523300141  20140623T000000  ...           1020        2007
# 21611   291310100  20150116T000000  ...           1410        1287
# 21612  1523300157  20141015T000000  ...           1020        1357
#
# [21613 rows x 21 columns]

# %%
dataframe.dtypes
# Out:
# id                 int64
# date              object
# price            float64
# bedrooms           int64
# bathrooms        float64
# sqft_living        int64
# sqft_lot           int64
# floors           float64
# waterfront         int64
# view               int64
# condition          int64
# grade              int64
# sqft_above         int64
# sqft_basement      int64
# yr_built           int64
# yr_renovated       int64
# zipcode            int64
# lat              float64
# long             float64
# sqft_living15      int64
# sqft_lot15         int64
# dtype: object

# %%
dataframe.describe()
# Out:
#                  id         price  ...  sqft_living15     sqft_lot15
# count  2.161300e+04  2.161300e+04  ...   21613.000000   21613.000000
# mean   4.580302e+09  5.400881e+05  ...    1986.552492   12768.455652
# std    2.876566e+09  3.671272e+05  ...     685.391304   27304.179631
# min    1.000102e+06  7.500000e+04  ...     399.000000     651.000000
# 25%    2.123049e+09  3.219500e+05  ...    1490.000000    5100.000000
# 50%    3.904930e+09  4.500000e+05  ...    1840.000000    7620.000000
# 75%    7.308900e+09  6.450000e+05  ...    2360.000000   10083.000000
# max    9.900000e+09  7.700000e+06  ...    6210.000000  871200.000000
#
# [8 rows x 20 columns]

# %% [markdown]
# **id** :a notation for a house
#
# **date:** Date house was sold
#
# **price:** Price is prediction target
#
# **bedrooms:** Number of Bedrooms/House
#
# **bathrooms:** Number of bathrooms/bedrooms
#
# **sqft_living:** square footage of the home
#
# **sqft_lot:** square footage of the lot
#
# **floors :**Total floors (levels) in house
#
# **waterfront :**House which has a view to a waterfront
#
# **view:** Has been viewed
#
# **condition :**How good the condition is Overall
#
# **grade:** overall grade given to the housing unit, based on King County grading system
#
# **sqft_above :**square footage of house apart from basement
#
# **sqft_basement:** square footage of the basement
#
# **yr_built :**Built Year
#
# **yr_renovated :**Year when house was renovated
#
# **zipcode:**zip code
#
# lat: Latitude coordinate
#
# **long:** Longitude coordinate
#
# **sqft_living15 :**Living room area in 2015(implies-- some renovations) This might or might not have affected the lotsize area
#
# **sqft_lot15 :**lotSize area in 2015(implies-- some renovations)**texte en gras**

# %%
dataframe.sum().isnull()
# Out:
# id               False
# date             False
# price            False
# bedrooms         False
# bathrooms        False
# sqft_living      False
# sqft_lot         False
# floors           False
# waterfront       False
# view             False
# condition        False
# grade            False
# sqft_above       False
# sqft_basement    False
# yr_built         False
# yr_renovated     False
# zipcode          False
# lat              False
# long             False
# sqft_living15    False
# sqft_lot15       False
# dtype: bool

# %% [markdown]
# **Notes:** In this phase "preprocessing data" we notice that the dataset is already clean, no missing data and well organised so we should move to next step which is data visualisation and analysation.

# %%
import matplotlib.pyplot as plt
print("visualisation of dataframes details")
dataframe.columns
# Out:
# visualisation of dataframes details
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'lat', 'long', 'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %%
import matplotlib.pyplot as plt
plt.ylabel('bedrooms')
plt.xlabel('price')
plt.title('Measure of price according to bedrooms')
arr1=np.array(dataframe['bedrooms'])
arr2=np.array(dataframe['price'])
plt.bar(arr1,arr2,color="pink")
plt.show()

# %%
import seaborn as sns
res = sns.lineplot(x="floors", y="price", data=dataframe)
plt.show()

# %%
import seaborn as sns
res = sns.pointplot(x=dataframe["bedrooms"], y=dataframe["price"], data=dataframe)
plt.show()

# %%
res = sns.lineplot(x=dataframe["grade"], y=dataframe["price"], data=dataframe)
plt.show()
##ax2+bx+c

# %%
res = sns.lineplot(x=dataframe["condition"], y=dataframe["price"], data=dataframe.head(100))
plt.show()

# %%
import seaborn as sns
sns.pairplot(dataframe, x_vars=['bedrooms', 'waterfront', 'bathrooms','condition'], y_vars='price', height=4, aspect=1, kind='scatter')
plt.show()

# %% [markdown]
# # How to read plots?
#  **For Bedrooms** like S+0,for minimum price, s+5 it's the most expensive houses and so for large houses more than 5 bedrooms the price will decrease.
# **Waterfront** if no waterfront there's no price else there's a sale for houses.
# **For bedrooms** we can apply linear regression due to it's plot behaviour.
# **Condition** : for condition 4 there's a maximum price means the most expensive and sold houses or elsewise houses are less exprensive.

# %%
sns.pairplot(dataframe, x_vars=['sqft_living15', 'sqft_lot', 'sqft_basement','grade'], y_vars='price', height=4, aspect=1, kind='scatter')
plt.show()

# %% [markdown]
# # Read Plots:
# ▶ **sqft_living15 ** in this case we can apply linear regression and polynomial regression.
# **sqft_lot** means square footage of lot so houses are more sold with no sqft_lot than other ones.
#  **sqft_basement** we can apply linear regression of course after deleting outlier from dataset.
#  **for Grade** it's pretty clear that we can apply polynomial regression.

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.boxplot(x="waterfront", y="price", data=dataframe)

# %% [markdown]
# ▶ Throw this lecture of boxplot, we notice that there's a lot of outlier that should be deleted from waterfront column in the dataset.

# %% [markdown]
# ▶ In this step we're going to delete "Date" column because we don't need it for regression, then we're going to standarize a unique scale for dataset.

# %%
from sklearn.preprocessing import StandardScaler 
import scipy.stats as ss
# Drop the "date"  columns
"""this line shoud be run once or you should delete dfscaled file"""
dataframe.drop(['date'], axis='columns', inplace=True)
dataframe
scaler = StandardScaler()
x = dataframe.values 
print(x)#returns a numpy array
x_scaled = scaler.fit_transform(dataframe.values)
df_scaled = pand.DataFrame(x_scaled,columns=dataframe.columns)
df_scaled =df_scaled.to_csv('dfscaled.csv')
# Out:
# [[ 7.12930052e+09  2.21900000e+05  3.00000000e+00 ... -1.22257000e+02
#    1.34000000e+03  5.65000000e+03]
#  [ 6.41410019e+09  5.38000000e+05  3.00000000e+00 ... -1.22319000e+02
#    1.69000000e+03  7.63900000e+03]
#  [ 5.63150040e+09  1.80000000e+05  2.00000000e+00 ... -1.22233000e+02
#    2.72000000e+03  8.06200000e+03]
#  ...
#  [ 1.52330014e+09  4.02101000e+05  2.00000000e+00 ... -1.22299000e+02
#    1.02000000e+03  2.00700000e+03]
#  [ 2.91310100e+08  4.00000000e+05  3.00000000e+00 ... -1.22069000e+02
#    1.41000000e+03  1.28700000e+03]
#  [ 1.52330016e+09  3.25000000e+05  2.00000000e+00 ... -1.22299000e+02
#    1.02000000e+03  1.35700000e+03]]

# %%
sns.pairplot(dataframe, x_vars=['yr_renovated', 'sqft_living', 'sqft_lot','sqft_living15','lat','long'], y_vars='price', height=4, aspect=1, kind='scatter')
plt.show()

# %% [markdown]
# Note :⚓ We notice that we can apply a linear regression for **sqft_living**
# and multi linear regression for **long,lat,sqft-lot**
# then we can make a polynomial regression for **grade** as example.

# %%
dfs= pand.read_csv('dfscaled.csv')
print("dataframe after standardisation ")
dfs
# Out:
# dataframe after standardisation
#        Unnamed: 0        id     price  ...      long  sqft_living15  sqft_lot15
# 0               0  0.886146 -0.866717  ... -0.306079      -0.943355   -0.260715
# 1               1  0.637511 -0.005688  ... -0.746341      -0.432686   -0.187868
# 2               2  0.365444 -0.980849  ... -0.135655       1.070140   -0.172375
# 3               3 -0.727656  0.174090  ... -1.271816      -0.914174   -0.284522
# 4               4 -0.912881 -0.081958  ...  1.199335      -0.272190   -0.192849
# ...           ...       ...       ...  ...       ...            ...         ...
# 21608       21608 -1.500888 -0.490545  ... -0.938069      -0.666135   -0.412381
# 21609       21609  0.702159 -0.381588  ... -1.051685      -0.228419   -0.203946
# 21610       21610 -1.062751 -0.375865  ... -0.604321      -1.410253   -0.394141
# 21611       21611 -1.491046 -0.381588  ...  1.028910      -0.841221   -0.420511
# ...

# %%
dfs.corr()['price'].sort_values()
# Out:
# zipcode         -0.053203
# id              -0.016762
# long             0.021626
# Unnamed: 0       0.027372
# condition        0.036362
# yr_built         0.054012
# sqft_lot15       0.082447
# sqft_lot         0.089661
# yr_renovated     0.126434
# floors           0.256794
# waterfront       0.266369
# lat              0.307003
# bedrooms         0.308350
# sqft_basement    0.323816
# view             0.397293
# bathrooms        0.525138
# sqft_living15    0.585379
# sqft_above       0.605567
# grade            0.667434
# sqft_living      0.702035
# price            1.000000
# Name: price, dtype: float64

# %%
sns.heatmap(dfs.corr(), annot = False)
plt.show()

# %% [markdown]
# **Description:**
#  ▶ the function sqft is positively correlated with price

# %%
print("Elimination of outliers")
upper_limit = dfs.head(1000).quantile(0.75)
lower_limit = dfs.head(1000).quantile(0.25)
IQR= upper_limit - lower_limit
dfs = dfs[(dfs < (lower_limit - 1.5 * IQR)) & (dfs > (upper_limit + 1.5 * IQR))]
print(dfs < (lower_limit - 1.5 * IQR)) and (dfs > (upper_limit + 1.5 * IQR))
##false means no outlier on board
# Out:
# Elimination of outliers
#        Unnamed: 0     id  price  ...   long  sqft_living15  sqft_lot15
# 0           False  False  False  ...  False          False       False
# 1           False  False  False  ...  False          False       False
# 2           False  False  False  ...  False          False       False
# 3           False  False  False  ...  False          False       False
# 4           False  False  False  ...  False          False       False
# ...           ...    ...    ...  ...    ...            ...         ...
# 21608       False  False  False  ...  False          False       False
# 21609       False  False  False  ...  False          False       False
# 21610       False  False  False  ...  False          False       False
# 21611       False  False  False  ...  False          False       False
# 21612       False  False  False  ...  False          False       False
#
# [21613 rows x 21 columns]

# %% [markdown]
# **Description ▶** the use of corr() show the linear relationship between  variables and price.

# %% [markdown]
# # Supervised Learning data #

# %% [markdown]
# **Linear Regression :**  y = β0 + β1X + var

# %%
import numpy as np
import pandas as pand 
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from sklearn import metrics
dfs = pand.read_csv('dfscaled.csv')
x = dfs[['sqft_living']]
y = dfs['price']

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.35, random_state = 40)
model= LinearRegression()  
model.fit(x_train, y_train)

model.fit(x_train,y_train)  
predicted=model.predict(x_test)
print('Intercept: ', model.intercept_)
print('Coefficient:', model.coef_)

print('Regression Equation: Sales = 6.948 + 0.054 * TV')


plt.scatter(x_train, y_train)
plt.plot(x_train, 0.00356 + 0.74*x_train, 'r')
plt.show()
print("MSE", mean_squared_error(y_test,predicted))
print("R squared", metrics.r2_score(y_test,predicted))
# Out:
# Intercept:  -0.00024276871412172473
# Coefficient: [0.7104884]
# Regression Equation: Sales = 6.948 + 0.054 * TV
# MSE 0.46671767916896095
# R squared 0.4996528488387416

# %%
x = dfs[['bathrooms']]
y = dfs['price']

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.35, random_state = 100)
model= LinearRegression()  
model.fit(x_train, y_train)

model.fit(x_train,y_train)  
predicted=model.predict(x_test)
print('Intercept: ', model.intercept_)
print('Coefficient:', model.coef_)

print('Regression Equation: Sales = 6.948 + 0.054 * TV')


plt.scatter(x_train, y_train)
plt.plot(x_train, 0.0086 + 0.518*x_train, 'green')
plt.show()
print("MSE", mean_squared_error(y_test,predicted))
print("R squared", metrics.r2_score(y_test,predicted))
# Out:
# Intercept:  0.001604187485882766
# Coefficient: [0.52890353]
# Regression Equation: Sales = 6.948 + 0.054 * TV
# MSE 0.7440755676591909
# R squared 0.26312340279485624

# %%
y_pred_slr= model.predict(x_test)  
x_pred_slr= model.predict(x_train)

print("Prediction for test set: {}".format(y_pred_slr))
# Out:
# Prediction for test set: [ 0.26617271  0.26617271  0.26617271 ...  0.26617271 -0.42058537
#  -0.07720633]

# %%
slr_diff = pand.DataFrame({'Actual value': y_test, 'Predicted value': y_pred_slr})
slr_diff
# Out:
#        Actual value  Predicted value
# 19836     -0.694838         0.266173
# 10442     -0.817551         0.266173
# 20548     -0.218153         0.266173
# 11014     -0.388398        -0.763964
# 4138       0.013379         0.952931
# ...             ...              ...
# 5614       0.571782         0.094483
# 16099     -0.122816         0.266173
# 7141       0.503684         0.266173
# 663       -0.621293        -0.420585
# 2795       0.571782        -0.077206
#
# [7565 rows x 2 columns]

# %%
from sklearn.metrics import accuracy_score
print('R squared value of the model: {:.2f}'.format(model.score(x_train,y_train)*100))
print('that means 28.27% of data fit that model ')
# Out:
# R squared value of the model: 28.27

# %% [markdown]
# # Multi-Linear Regression :
# f1 :long is the size of the house.
#
# f2 : bedrooms is bad rooms in the house.
#
# f3 : waterfront is the locality of the house.
#
# f4 :condition is the condition of the house and,
#
# f5 : price is our output feature which is the price of the house.
# ** equation: Formula: Y = β0 + β1X1 + β2X2 + β3X3 + ... + βnXn + e**

# %%
features =["floors", "waterfront","lat" ,"bedrooms" ,"sqft_basement" ,"view" ,"bathrooms","sqft_living15","sqft_above","grade","sqft_living"]
print("list of features",features)
# Out:
# list of features ['floors', 'waterfront', 'lat', 'bedrooms', 'sqft_basement', 'view', 'bathrooms', 'sqft_living15', 'sqft_above', 'grade', 'sqft_living']

# %%
x = dfs[['sqft_living', 'waterfront', 'bathrooms','bedrooms','view']]
y = dfs['price']

x_train, x_test, y_train, y_test= train_test_split(x, y, test_size= 0.3, random_state=100)
model= LinearRegression()  
model.fit(x_train, y_train)

##plt.scatter(x_train, y_train)
plt.plot(x,2.71828 + 0.005 + 0.71*dfs['sqft_living']+0.14*dfs['waterfront']+0.016*dfs['bathrooms']-0.113*dfs['bedrooms']+0.144*dfs['view'], 'pink')
plt.show()
#Printing the model coefficients
print("intercept",model.intercept_)
print("coef",model.coef_)
# pair the feature names with the coefficients
list(zip(x, model.coef_))
y_pred_mlr= model.predict(x_test)
meanAbErr = metrics.mean_absolute_error(y_test, y_pred_mlr)
meanSqErr = metrics.mean_squared_error(y_test, y_pred_mlr)
rootMeanSqErr = np.sqrt(metrics.mean_squared_error(y_test, y_pred_mlr))

print('Mean Absolute Error:', meanAbErr)
print('Mean Square Error:', meanSqErr)
print('Root Mean Square Error:', rootMeanSqErr)
# Out:
# intercept 0.0010939872274003503
# coef [ 0.67873418  0.14499077  0.03221559 -0.10761356  0.14119049]
# Mean Absolute Error: 0.44094817782472157
# Mean Square Error: 0.4428322750561471
# Root Mean Square Error: 0.6654564411410766

# %%
x = dfs[['sqft_lot', 'lat', 'long']]
y = dfs['price']

x_train, x_test, y_train, y_test= train_test_split(x, y, test_size= 0.3, random_state=50)
model= LinearRegression()  
model.fit(x_train, y_train)

##plt.scatter(x_train, y_train)
plt.plot(x,2.71828 + 0.005 + 0.71*dfs['sqft_lot']+0.14*dfs['lat']+0.016*dfs['long'], 'pink')
plt.show()
#Printing the model coefficients
print("intercept",model.intercept_)
print("coef",model.coef_)
# pair the feature names with the coefficients
list(zip(x, model.coef_))
y_pred_mlr= model.predict(x_test)
meanAbErr = metrics.mean_absolute_error(y_test, y_pred_mlr)
meanSqErr = metrics.mean_squared_error(y_test, y_pred_mlr)
rootMeanSqErr = np.sqrt(metrics.mean_squared_error(y_test, y_pred_mlr))
# Out:
# intercept -0.002908359561569823
# coef [0.10833607 0.32019616 0.04139281]

# %%
print("Prediction for test set: {}".format(y_pred_mlr))
# Out:
# Prediction for test set: [-0.05725138 -0.18107826 -0.43942705 ...  0.38565785 -0.05920696
#  -0.46736753]

# %%
mlr_diff = pand.DataFrame({'Actual value': y_test, 'Predicted value': y_pred_mlr})
slr_diff.head()
# Out:
#        Actual value  Predicted value
# 19836     -0.694838         0.266173
# 10442     -0.817551         0.266173
# 20548     -0.218153         0.266173
# 11014     -0.388398        -0.763964
# 4138       0.013379         0.952931

# %%
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures 
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score
# create matrix and vectors
x = dfs[["bedrooms", "bathrooms","floors"]]
y = dfs["price"]
lg = LinearRegression() 
poly = PolynomialFeatures(degree = 2)
##[1, x1, x2, x1^2, x1*x2, x2^2].
print(poly)
print("linear regression model")
#Setting the value for X and Y
x_train, x_test, y_train, y_test= train_test_split(x, y, test_size= 0.8, random_state=60)
mlr= LinearRegression()  
mlr.fit(x_train, y_train)

LinearRegression()

#Printing the model coefficients
print(mlr.intercept_)
# pair the feature names with the coefficients
list(zip(x, mlr.coef_))
print('R squared value of the test model: {:.2f}'.format(mlr.score(x_test,y_test)*100))
print('R squared value of the train model: {:.2f}'.format(mlr.score(x_train,y_train)*100))
# Out:
# PolynomialFeatures()
# linear regression model
# 0.006928151207478826
# R squared value of the test model: 27.57
# R squared value of the train model: 28.58

# %% [markdown]
# **Polynomial Regression With scikit-learn**

# %%
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures

x = np.array(dfs["sqft_living"]).reshape((-1, 1))
y = np.array(dfs["price"])
transformer = PolynomialFeatures(degree=2, include_bias=False)
transformer.fit(x)
x__ = transformer.transform(x)
x_ = PolynomialFeatures(degree=2, include_bias=False).fit_transform(x)
print(x_)
# Out:
# [[-0.97983502  0.96007667]
#  [ 0.53363434  0.28476561]
#  [-1.42625404  2.03420059]
#  ...
#  [-1.15404732  1.33182522]
#  [-0.52252773  0.27303523]
#  [-1.15404732  1.33182522]]

# %%
model = LinearRegression().fit(x_, y)
r_sq = model.score(x_, y)
print('coefficient of determination:', r_sq)
print('intercept:', model.intercept_)
print('coefficients:', model.coef_)
# Out:
# coefficient of determination: 0.5327430940591444
# intercept: -0.08864459097373349
# coefficients: [0.57159868 0.08864459]

# %%
y_pred = model.predict(x_)
print('predicted response:', y_pred, sep='\n')
# Out:
# predicted response:
# [-0.56361139  0.24162302 -0.72356864 ... -0.63023741 -0.36311766
#  -0.63023741]

# %% [markdown]
# **R squared value of the model: 27.97 =>** that means that 27.97% of data fit the regression model

# %%
x= dfs[["sqft_living", "sqft_above"]]
y= dfs["price"].values

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.35, random_state=40)  #splitting data
lg=LinearRegression()
poly=PolynomialFeatures(degree=3)

x_train_fit = poly.fit_transform(x_train) #transforming our input data
lg.fit(x_train_fit, y_train)
x_test_ = poly.fit_transform(x_test)
predicted = lg.predict(x_test_)

print("MSE: ", metrics.mean_squared_error(y_test, predicted))
print("R squared: ", metrics.r2_score(y_test,predicted))
# Out:
# MSE:  0.4246472176368648
# R squared:  0.5447547091606069

# %% [markdown]
# **Analyse the prediction**, in this case  R^2 means that 54% of data fit the predicted model and only 42% doe not fit that model so it's excellent.

# %%
x= dfs["sqft_lot"].values.reshape(-1,1)
y= dfs["price"].values
poly = PolynomialFeatures(degree = 2) 
x_poly = poly.fit_transform(x) 
poly.fit(x_poly, y) 
lg=LinearRegression()
lg.fit(x_poly, y) 

plt.scatter(x, y, color="pink")
plt.title("polynomial regression")
plt.ylabel("sqft_lot")
plt.xlabel("price")
plt.plot(x, lg.predict(poly.fit_transform(x)), color="k")

# %%
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression
from sklearn.pipeline import Pipeline
Input=[('polynomial',PolynomialFeatures(degree=3)),('modal',LinearRegression())]
pipe=Pipeline(Input)
pipe.fit(x.reshape(-1,1),y.reshape(-1,1))
poly_pred=pipe.predict(x.reshape(-1,1))

lin_reg=LinearRegression()
x= dfs["grade"].values.reshape(-1,1)
y= dfs["price"].values
lin_reg.fit(x,y)

poly_reg=PolynomialFeatures(degree=3)
X_poly=poly_reg.fit_transform(x)
poly_reg.fit(X_poly,y)
lin_reg2=LinearRegression()
lin_reg2.fit(X_poly,y)
print('RMSE for Linear Regression=>',np.sqrt(mean_squared_error(y,lin_reg.predict(x))))
print('RMSE for Polynomial Regression=>',np.sqrt(mean_squared_error(y,poly_pred)))
#Visualisng the linear regression model results
plt.scatter(x,y,color='pink')
plt.plot(x,lin_reg.predict(x),color='blue')
plt.title('(Linear Regression)')
plt.xlabel('grade')
plt.ylabel('price')
plt.show()
# Out:
# RMSE for Linear Regression=> 0.744668727616994
# RMSE for Polynomial Regression=> 0.9929358161562851

# %% [markdown]
# RMSE of polynomial regression is lower than RMSE of linear regression due to precision.

# %%
#Visualising the pollynomial regression model results
X_grid=np.arange(min(x),max(x),0.1)
X_grid=X_grid.reshape((len(X_grid),1))
plt.scatter(x,y,color='pink')
plt.plot(x,lin_reg2.predict(poly_reg.fit_transform(x)),color='blue')
plt.title('(Polynomial Regression)')
plt.xlabel('grade')
plt.ylabel('price')
plt.show()

# %% [markdown]
# Polynome pediction is closer to real values than linear regression predicted model.
