# %% [markdown]
# <a href="https://colab.research.google.com/github/nouha18/pythoncheckpoint/blob/update/checkpoint3_updates.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
###checkpoint4
import pandas as pand
### tester un fichier csv 
col_list = ["PassengerId","Survived","Pclass","Name","Sex","Age","SibSp","Parch","Ticket","Cabin"]
df = pand.read_csv("titanic.csv")
df.describe(percentiles = [.75, .8])
# Out:
#        PassengerId    Survived      Pclass  ...       SibSp       Parch        Fare
# count   891.000000  891.000000  891.000000  ...  891.000000  891.000000  891.000000
# mean    446.000000    0.383838    2.308642  ...    0.523008    0.381594   32.204208
# std     257.353842    0.486592    0.836071  ...    1.102743    0.806057   49.693429
# min       1.000000    0.000000    1.000000  ...    0.000000    0.000000    0.000000
# 50%     446.000000    0.000000    3.000000  ...    0.000000    0.000000   14.454200
# 75%     668.500000    1.000000    3.000000  ...    1.000000    0.000000   31.000000
# 80%     713.000000    1.000000    3.000000  ...    1.000000    1.000000   39.687500
# max     891.000000    1.000000    3.000000  ...    8.000000    6.000000  512.329200
#
# [8 rows x 7 columns]

# %%
df
# Out:
#      PassengerId  Survived  Pclass  ...     Fare Cabin  Embarked
# 0              1         0       3  ...   7.2500   NaN         S
# 1              2         1       1  ...  71.2833   C85         C
# 2              3         1       3  ...   7.9250   NaN         S
# 3              4         1       1  ...  53.1000  C123         S
# 4              5         0       3  ...   8.0500   NaN         S
# ..           ...       ...     ...  ...      ...   ...       ...
# 886          887         0       2  ...  13.0000   NaN         S
# 887          888         1       1  ...  30.0000   B42         S
# 888          889         0       3  ...  23.4500   NaN         S
# 889          890         1       1  ...  30.0000  C148         C
# 890          891         0       3  ...   7.7500   NaN         Q
#
# [891 rows x 12 columns]

# %% [markdown]
# Dans la partie **data-cleaning** ci-dessous nous allons faire la selection des valeurs NaN et les enlevées

# %%
###checkpoint 3
import pandas as pand
import random
col_list = ["PassengerId","Survived","Pclass","Name","Sex","Age","SibSp","Parch","Ticket","Fare","Cabin"]
df = pand.read_csv("titanic-passengers.csv",sep=";")
print('this is a sum of nan values of All columns',df.isnull().sum())
##PassengerId      0
##Survived         0
##Pclass         891
##Name           891
##Sex            891
##Age              0
##SibSp          891
##Parch          891
##Ticket         891
##Fare           891
##Cabin

df["Age"] = df["Age"].fillna(random.randint(15,70))

##print(df["Survived"])
df["Survived"].fillna("survived",inplace=True)

df.isnull().sum()
df["Name"].fillna("Name ,Mr. Xperson",inplace=True)

print(df["Pclass"])
df.isnull().sum()
df["Pclass"].fillna("underclass",inplace=True)

print(df["SibSp"])
df.isnull()
df["SibSp"].fillna("Sibling"+str(random.randint(1,1461)),inplace=True)

print('Parch columns ******') 
df["Parch"].isnull().sum()
print(df["Parch"].fillna("Parent"+str(random.randint(1,1461)),inplace=True))
print('genre columns ******')
df["Sex"].isnull().sum()
print(df["Sex"].fillna("female",inplace=True))

print('Ticket columns ******')
##on exploite les valeurs de la colonne Ticket pour mieux choisir les valeurs a modifiées
df["Ticket"]
df["Ticket"].isnull().sum()
df["Ticket"].fillna("Ticket"+str(random.randint(1,1461)),inplace=True)
df["Fare"]
##df["Fare"].fillna(df["Fare"].median(),inplace=True)
df["Fare"]=df["Fare"].fillna(random.randint(1,19))
print('Cabin columns ******'+df["Cabin"])
print('Embarked columns ******')
df["Embarked"]=df["Embarked"].fillna(df["Embarked"].value_counts(ascending=True))
df["Cabin"].fillna("VIP",inplace=True)
df["Cabin"].isnull().sum()

print("nombre des valeurs null",df.isnull().sum())
final_df = df
##export as dataframe with "," separator
file = final_df.to_csv('cleandata.csv')
# Out:
# this is a sum of nan values of All columns PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64
# 0      2
# 1      3
# 2      3
# 3      3
# 4      1
#       ..
# 886    2
# 887    3
# 888    3
# 889    3
# 890    2
# Name: Pclass, Length: 891, dtype: int64
# 0      0
# 1      0
# 2      0
# 3      0
# 4      1
#       ..
# 886    1
# 887    0
# 888    0
# 889    0
# 890    0
# Name: SibSp, Length: 891, dtype: int64
# Parch columns ******
# None
# genre columns ******
# None
# Ticket columns ******
# 0                            NaN
# 1      Cabin columns ******F G73
# 2                            NaN
# 3                            NaN
# 4        Cabin columns ******B71
#                  ...
# 886                          NaN
# 887                          NaN
# 888                          NaN
# 889                          NaN
# 890                          NaN
# Name: Cabin, Length: 891, dtype: object
# Embarked columns ******
# nombre des valeurs null PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          0
# Embarked       2
# dtype: int64

# %%
df.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          0
# Embarked       2
# dtype: int64

# %% [markdown]
# Cette partie, disons le **data-visualisation**, concerne
# l'affichage des données selon des axes déterminés.

# %%
import pandas as pand
import numpy as np
import matplotlib.pyplot as plt
col_list = ["PassengerId","Survived","Pclass","Name","Sex","Age","SibSp","Parch","Ticket","Fare","Cabin"]
dfile = pand.read_csv("titanic.csv")
print("final preprocessing result ")
print(dfile.describe(include = 'all'))


## Data-visualisation 

plt.xlabel("Age")
plt.ylabel("Survived")
plt.title("plot Survived people by Name")
###################
arr1=np.array(dfile["Age"].head(70))
arr2=np.array(dfile["Sex"].head(70))
## Data-visualisation 
plt.xlabel("Age") 
plt.ylabel("Sex")
plt.title("Visualisation of the categories of survived ")

##plt.plot(array1,array2)
plt.bar(arr2,arr1,color="#69b3a2")
plt.show()
# Out:
# final preprocessing result
#         PassengerId    Survived      Pclass  ...        Fare    Cabin  Embarked
# count    891.000000  891.000000  891.000000  ...  891.000000      204       889
# unique          NaN         NaN         NaN  ...         NaN      147         3
# top             NaN         NaN         NaN  ...         NaN  B96 B98         S
# freq            NaN         NaN         NaN  ...         NaN        4       644
# mean     446.000000    0.383838    2.308642  ...   32.204208      NaN       NaN
# std      257.353842    0.486592    0.836071  ...   49.693429      NaN       NaN
# min        1.000000    0.000000    1.000000  ...    0.000000      NaN       NaN
# 25%      223.500000    0.000000    2.000000  ...    7.910400      NaN       NaN
# 50%      446.000000    0.000000    3.000000  ...   14.454200      NaN       NaN
# 75%      668.500000    1.000000    3.000000  ...   31.000000      NaN       NaN
# max      891.000000    1.000000    3.000000  ...  512.329200      NaN       NaN
#
# [11 rows x 12 columns]

# %%
import pandas as pand
import numpy as np
import matplotlib.pyplot as plt
col_list = ["PassengerId","Survived","Pclass","Name","Sex","Age","SibSp","Parch","Ticket","Fare","Cabin"]
dfile = pand.read_csv("titanic.csv")
print("final preprocessing result ")
print(dfile.columns)

array1=np.array(dfile["Name"])
array2=np.array(dfile["Cabin"])

## Data-visualisation 

plt.xlabel("Pclass")
plt.ylabel("Fare")
plt.title("plot people by Name in Cabin")
###################
arr1=np.array(dfile["Pclass"].head(1000))
arr2=np.array(dfile["Fare"].head(1000))


##plt.plot(array1,array2)
plt.bar(arr2,arr1,color = "blue")
plt.show()
# Out:
# final preprocessing result
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %% [markdown]
# Use the groupby function combined with the mean() to view the relation between Pclass and survived

# %%
import pandas as pand
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
col_list = ["PassengerId","Survived","Pclass","Name","Sex","Age","SibSp","Parch","Ticket","Fare","Cabin"]
dfile = pand.read_csv("titanic.csv")
print("final preprocessing result ")
print(dfile.columns)
##print(type(df.groupby('Name').mean()))
dfile.groupby('Name').mean()
dfile.groupby('Sex').sum().reset_index().head(1000)
dfile.groupby('PassengerId').sum().plot(kind='bar');
dfile.groupby(['Pclass', 'Survived'] )['Survived'].count().plot.bar(figsize=(8, 6));
print("Visualisation d'une autre façon")
plt.figure(figsize = (15, 6))
#plt.axis([1,3,0,1])
dfile[['Pclass', 'Survived']].groupby(['Pclass'], as_index = False).mean().sort_values('Survived', ascending = False)
# Out:
# final preprocessing result
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')
# Visualisation d'une autre façon
#    Pclass  Survived
# 0       1  0.629630
# 1       2  0.472826
# 2       3  0.242363

# %%
sns.violinplot(data = dfile, x = 'Name', y = 'Survived')

# %%
import seaborn as sns
import pandas as pand
import numpy as np
import matplotlib.pyplot as plt
dfile = pand.read_csv("titanic.csv")
print("Correlation result ")
###########################
def plot_correlation_map( dfile ):

        corr = dfile.corr()
        sns.set_theme(style="white")
        # Set up the matplotlib figure
        s , ax = plt.subplots( figsize =( 11 , 9 ) )
        cmap = sns.diverging_palette( 220 , 10 , as_cmap = True )

        s = sns.heatmap(

        corr, 

        cmap = cmap,

        square=True, 

        cbar_kws={ 'shrink' : .9 }, 

        ax=ax, 

        annot = True, 

        annot_kws = { 'fontsize' : 12 }

        )
        plt.show()
        
        
print(plot_correlation_map( dfile ))
# Out:
# Correlation result
# None

# %% [markdown]
# **Description of Plot:**
# Dans ce diagramme on remarque que la variation des couleurs varie du rose vif vers le bleu intense du plus intense vers le moins intense.
# plus la relation est intense entre les deux paramètres et plus la couleurs tend vers le rose donc vers la valeur=1
# si non elle tend vers le beu de valeur null ou négative.

# %% [markdown]
# **More :**
# Ticket feature may be dropped from our analysis as it contains high ratio of duplicates (22%) and there may not be a correlation between Ticket and survival.
# Cabin feature may be dropped as it is highly incomplete or contains many null values both in training and test dataset.
# PassengerId may be dropped from training dataset as it does not contribute to survival.
# Pclass We observe significant correlation (>0.5) among Pclass=1 and Survived.
# Sex We confirm the observation during problem definition that Sex=female had very high survival rate at 74%.
# Name feature is relatively non-standard, may not contribute directly to survival, so maybe dropped. We may want to engineer the Name feature to extract Title as a new feature.
# We may want to complete Age and the Embarked feature as they are correlated to survival or another important feature
# We may want to create new feature for Age bands. This turns a continous numerical feature into an ordinal categorical feature.
# We may want to create a new feature called Family based on Parch and SibSp to get total count of family members on board.
# We may also want to create a Fare range feature if it helps our analysis

# %%
Title_Dic = {
    "Capt":       "Officer",
    "Col":        "Officer",
    "Major":      "Officer",
    "Dr":         "Officer",
    "Rev":        "Officer",
    "Jonkheer":   "Royalty",
    "Don":        "Royalty",
    "Sir" :       "Royalty",
    " Lady" :      "Royalty",
    "the Countess" : "Royalty",
    "Dona" :       "Royalty",
    "Mme" :        "Miss",
    "Mlle" :       "Miss",
    "Miss" :      "Miss",
    "Ms" :         "Mrs",
    "Mr"  :        "Mrs",
    "Mrs" :       "Mrs",
     "Master" :    "Master"
    }
titles=df["Name"].str.split(", ")
titles_extracted=[]
for element in titles:
  titles_extracted.append(element[1].split(".")[0])
df["Title"]=titles_extracted
df=df.replace({"Title": Title_Dic})
set(df["Title"])
# Out:
# {'Lady', 'Master', 'Miss', 'Mrs', 'Officer', 'Royalty'}

# %%
###As a final step try to drop the useless columns such as Names

import seaborn as sns
import pandas as pand
import numpy as np
import matplotlib.pyplot as plt
dfile = pand.read_csv("titanic.csv")
print("Drop column Name result ")
###########################################
print(dfile.shape)

# Drop the 'county_name' and 'state' columns
dfile.drop(['Name'], axis='columns', inplace=True)
file = dfile.to_csv('finaldata.csv')
df = pand.read_csv("finaldata.csv")
# Out:
# Drop column Name result
# (891, 12)

# %%
###checkpoint 3
import pandas as pand
import re
Title_Dic = {
    "Capt":       "Officer",
    "Col":        "Officer",
    "Major":      "Officer",
    "Dr":         "Officer",
    "Rev":        "Officer",
    "Jonkheer":   "Royalty",
    "Don":        "Royalty",
    "Sir" :       "Royalty",
    " Lady" :      "Royalty",
    "the Countess" : "Royalty",
    "Dona" :       "Royalty",
    "Mme" :        "Miss",
    "Mlle" :       "Miss",
    "Miss" :      "Miss",
    "Ms" :         "Mrs",
    "Mr"  :        "Mrs",
    "Mrs" :       "Mrs",
     "Master" :    "Master"
    }
### extract title from Name column
df = pand.read_csv("titanic.csv")

try:  
    for i in df.index:
        substring =  df["Name"][i][ df["Name"][i].index(",")+1: df["Name"][i].index(".")].split(' ')
        for key in Title_Dic:
              if (key == substring[1]):
                x = df["Name"][i].replace(substring[1],Title_Dic[key])
                print(x)
                print(df["Name"][i].replace(substring[1],Title_Dic[key]))
                ##df=df.replace({"Title": Title_Dic})
except AttributeError:
    pass


set(df["Name"].unique())
# Out:
# Braund, Mrs. Owen Harris
# Braund, Mrs. Owen Harris
# Cumings, Mrs. John Bradley (Florence Briggs Thayer)
# Cumings, Mrs. John Bradley (Florence Briggs Thayer)
# Heikkinen, Miss. Laina
# Heikkinen, Miss. Laina
# Futrelle, Mrs. Jacques Heath (Lily May Peel)
# Futrelle, Mrs. Jacques Heath (Lily May Peel)
# Allen, Mrs. William Henry
# Allen, Mrs. William Henry
# Moran, Mrs. James
# Moran, Mrs. James
# McCarthy, Mrs. Timothy J
# McCarthy, Mrs. Timothy J
# Palsson, Master. Gosta Leonard
# Palsson, Master. Gosta Leonard
# Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# Nasser, Mrs. Nicholas (Adele Achem)
# Nasser, Mrs. Nicholas (Adele Achem)
# Sandstrom, Miss. Marguerite Rut
# Sandstrom, Miss. Marguerite Rut
# Bonnell, Miss. Elizabeth
# Bonnell, Miss. Elizabeth
# Saundercock, Mrs. William Henry
# Saundercock, Mrs. William Henry
# Andersson, Mrs. Anders Johan
# Andersson, Mrs. Anders Johan
# Vestrom, Miss. Hulda Amanda Adolfina
# Vestrom, Miss. Hulda Amanda Adolfina
# Hewlett, Mrs. (Mary D Kingcome)
# Hewlett, Mrs. (Mary D Kingcome)
# Rice, Master. Eugene
# Rice, Master. Eugene
# Williams, Mrs. Charles Eugene
# Williams, Mrs. Charles Eugene
# Vander Planke, Mrs. Julius (Emelia Maria Vandemoortele)
# Vander Planke, Mrs. Julius (Emelia Maria Vandemoortele)
# Masselmani, Mrs. Fatima
# Masselmani, Mrs. Fatima
# Fynney, Mrs. Joseph J
# Fynney, Mrs. Joseph J
# Beesley, Mrs. Lawrence
# Beesley, Mrs. Lawrence
# McGowan, Miss. Anna "Annie"
# McGowan, Miss. Anna "Annie"
# Sloper, Mrs. William Thompson
# Sloper, Mrs. William Thompson
# Palsson, Miss. Torborg Danira
# Palsson, Miss. Torborg Danira
# Asplund, Mrs. Carl Oscar (Selma Augusta Emilia Johansson)
# Asplund, Mrs. Carl Oscar (Selma Augusta Emilia Johansson)
# Emir, Mrs. Farred Chehab
# Emir, Mrs. Farred Chehab
# Fortune, Mrs. Charles Alexander
# Fortune, Mrs. Charles Alexander
# O'Dwyer, Miss. Ellen "Nellie"
# O'Dwyer, Miss. Ellen "Nellie"
# Todoroff, Mrs. Lalio
# Todoroff, Mrs. Lalio
# Uruchurtu, Royalty. Manuel E
# Uruchurtu, Royalty. Manuel E
# Spencer, Mrs. William Augustus (Marie Eugenie)
# Spencer, Mrs. William Augustus (Marie Eugenie)
# Glynn, Miss. Mary Agatha
# Glynn, Miss. Mary Agatha
# Wheadon, Mrs. Edward H
# Wheadon, Mrs. Edward H
# Meyer, Mrs. Edgar Joseph
# Meyer, Mrs. Edgar Joseph
# Holverson, Mrs. Alexander Oskar
# Holverson, Mrs. Alexander Oskar
# Mamee, Mrs. Hanna
# Mamee, Mrs. Hanna
# Cann, Mrs. Ernest Charles
# Cann, Mrs. Ernest Charles
# Vander Planke, Miss. Augusta Maria
# Vander Planke, Miss. Augusta Maria
# Nicola-Yarred, Miss. Jamila
# Nicola-Yarred, Miss. Jamila
# Ahlin, Mrs. Johan (Johanna Persdotter Larsson)
# Ahlin, Mrs. Johan (Johanna Persdotter Larsson)
# Turpin, Mrs. William John Robert (Dorothy Ann Wonnacott)
# Turpin, Mrs. William John Robert (Dorothy Ann Wonnacott)
# Kraeff, Mrs. Theodor
# Kraeff, Mrs. Theodor
# Laroche, Miss. Simonne Marie Anne Andree
# Laroche, Miss. Simonne Marie Anne Andree
# Devaney, Miss. Margaret Delia
# Devaney, Miss. Margaret Delia
# Rogers, Mrs. William John
# Rogers, Mrs. William John
# Lennon, Mrs. Denis
# Lennon, Mrs. Denis
# O'Driscoll, Miss. Bridget
# O'Driscoll, Miss. Bridget
# Samaan, Mrs. Youssef
# Samaan, Mrs. Youssef
# Arnold-Franchi, Mrs. Josef (Josefine Franchi)
# Arnold-Franchi, Mrs. Josef (Josefine Franchi)
# Panula, Master. Juha Niilo
# Panula, Master. Juha Niilo
# Nosworthy, Mrs. Richard Cater
# Nosworthy, Mrs. Richard Cater
# Harper, Mrs. Henry Sleeper (Myna Haxtun)
# Harper, Mrs. Henry Sleeper (Myna Haxtun)
# Faunthorpe, Mrs. Lizzie (Elizabeth Anne Wilkinson)
# Faunthorpe, Mrs. Lizzie (Elizabeth Anne Wilkinson)
# Ostby, Mrs. Engelhart Cornelius
# Ostby, Mrs. Engelhart Cornelius
# Woolner, Mrs. Hugh
# Woolner, Mrs. Hugh
# Rugg, Miss. Emily
# Rugg, Miss. Emily
# Novel, Mrs. Mansouer
# Novel, Mrs. Mansouer
# West, Miss. Constance Mirium
# West, Miss. Constance Mirium
# Goodwin, Master. William Frederick
# Goodwin, Master. William Frederick
# Sirayanian, Mrs. Orsen
# Sirayanian, Mrs. Orsen
# Icard, Miss. Amelie
# Icard, Miss. Amelie
# Harris, Mrs. Henry Birkhardt
# Harris, Mrs. Henry Birkhardt
# Skoog, Master. Harald
# Skoog, Master. Harald
# Stewart, Mrs. Albert A
# Stewart, Mrs. Albert A
# Moubarek, Master. Gerios
# Moubarek, Master. Gerios
# Nye, Mrs. (Elizabeth Ramell)
# Nye, Mrs. (Elizabeth Ramell)
# Crease, Mrs. Ernest James
# Crease, Mrs. Ernest James
# Andersson, Miss. Erna Alexandra
# Andersson, Miss. Erna Alexandra
# Kink, Mrs. Vincenz
# Kink, Mrs. Vincenz
# Jenkin, Mrs. Stephen Curnow
# Jenkin, Mrs. Stephen Curnow
# Goodwin, Miss. Lillian Amy
# Goodwin, Miss. Lillian Amy
# Hood, Mrs. Ambrose Jr
# Hood, Mrs. Ambrose Jr
# Chronopoulos, Mrs. Apostolos
# Chronopoulos, Mrs. Apostolos
# Bing, Mrs. Lee
# Bing, Mrs. Lee
# Moen, Mrs. Sigurd Hansen
# Moen, Mrs. Sigurd Hansen
# Staneff, Mrs. Ivan
# Staneff, Mrs. Ivan
# Moutal, Mrs. Rahamin Haim
# Moutal, Mrs. Rahamin Haim
# Caldwell, Master. Alden Gates
# Caldwell, Master. Alden Gates
# Dowdell, Miss. Elizabeth
# Dowdell, Miss. Elizabeth
# Waelens, Mrs. Achille
# Waelens, Mrs. Achille
# Sheerlinck, Mrs. Jan Baptist
# Sheerlinck, Mrs. Jan Baptist
# McDermott, Miss. Brigdet Delia
# McDermott, Miss. Brigdet Delia
# Carrau, Mrs. Francisco M
# Carrau, Mrs. Francisco M
# Ilett, Miss. Bertha
# Ilett, Miss. Bertha
# Backstrom, Mrs. Karl Alfred (Maria Mathilda Gustafsson)
# Backstrom, Mrs. Karl Alfred (Maria Mathilda Gustafsson)
# Ford, Mrs. William Neal
# Ford, Mrs. William Neal
# Slocovski, Mrs. Selman Francis
# Slocovski, Mrs. Selman Francis
# Fortune, Miss. Mabel Helen
# Fortune, Miss. Mabel Helen
# Celotti, Mrs. Francesco
# Celotti, Mrs. Francesco
# Christmann, Mrs. Emil
# Christmann, Mrs. Emil
# Andreasson, Mrs. Paul Edvin
# Andreasson, Mrs. Paul Edvin
# Chaffee, Mrs. Herbert Fuller
# Chaffee, Mrs. Herbert Fuller
# Dean, Mrs. Bertram Frank
# Dean, Mrs. Bertram Frank
# Coxon, Mrs. Daniel
# Coxon, Mrs. Daniel
# Shorney, Mrs. Charles Joseph
# Shorney, Mrs. Charles Joseph
# Goldschmidt, Mrs. George B
# Goldschmidt, Mrs. George B
# Greenfield, Mrs. William Bertram
# Greenfield, Mrs. William Bertram
# Doling, Mrs. John T (Ada Julia Bone)
# Doling, Mrs. John T (Ada Julia Bone)
# Kantor, Mrs. Sinai
# Kantor, Mrs. Sinai
# Petranec, Miss. Matilda
# Petranec, Miss. Matilda
# Petroff, Mrs. Pastcho ("Pentcho")
# Petroff, Mrs. Pastcho ("Pentcho")
# White, Mrs. Richard Frasar
# White, Mrs. Richard Frasar
# Johansson, Mrs. Gustaf Joel
# Johansson, Mrs. Gustaf Joel
# Gustafsson, Mrs. Anders Vilhelm
# Gustafsson, Mrs. Anders Vilhelm
# Mionoff, Mrs. Stoytcho
# Mionoff, Mrs. Stoytcho
# Salkjelsvik, Miss. Anna Kristine
# Salkjelsvik, Miss. Anna Kristine
# Moss, Mrs. Albert Johan
# Moss, Mrs. Albert Johan
# Rekic, Mrs. Tido
# Rekic, Mrs. Tido
# Moran, Miss. Bertha
# Moran, Miss. Bertha
# Porter, Mrs. Walter Chamberlain
# Porter, Mrs. Walter Chamberlain
# Zabour, Miss. Hileni
# Zabour, Miss. Hileni
# Barton, Mrs. David John
# Barton, Mrs. David John
# Jussila, Miss. Katriina
# Jussila, Miss. Katriina
# Attalah, Miss. Malake
# Attalah, Miss. Malake
# Pekoniemi, Mrs. Edvard
# Pekoniemi, Mrs. Edvard
# Connors, Mrs. Patrick
# Connors, Mrs. Patrick
# Turpin, Mrs. William John Robert
# Turpin, Mrs. William John Robert
# Baxter, Mrs. Quigg Edmond
# Baxter, Mrs. Quigg Edmond
# Andersson, Miss. Ellis Anna Maria
# Andersson, Miss. Ellis Anna Maria
# Hickman, Mrs. Stanley George
# Hickman, Mrs. Stanley George
# Moore, Mrs. Leonard Charles
# Moore, Mrs. Leonard Charles
# Nasser, Mrs. Nicholas
# Nasser, Mrs. Nicholas
# Webber, Miss. Susan
# Webber, Miss. Susan
# White, Mrs. Percival Wayland
# White, Mrs. Percival Wayland
# Nicola-Yarred, Master. Elias
# Nicola-Yarred, Master. Elias
# McMahon, Mrs. Martin
# McMahon, Mrs. Martin
# Madsen, Mrs. Fridtjof Arne
# Madsen, Mrs. Fridtjof Arne
# Peter, Miss. Anna
# Peter, Miss. Anna
# Ekstrom, Mrs. Johan
# Ekstrom, Mrs. Johan
# Drazenoic, Mrs. Jozef
# Drazenoic, Mrs. Jozef
# Coelho, Mrs. Domingos Fernandeo
# Coelho, Mrs. Domingos Fernandeo
# Robins, Mrs. Alexander A (Grace Charity Laury)
# Robins, Mrs. Alexander A (Grace Charity Laury)
# Weisz, Mrs. Leopold (Mathilde Francoise Pede)
# Weisz, Mrs. Leopold (Mathilde Francoise Pede)
# Sobey, Mrs. Samuel James Hayden
# Sobey, Mrs. Samuel James Hayden
# Richard, Mrs. Emile
# Richard, Mrs. Emile
# Newsom, Miss. Helen Monypeny
# Newsom, Miss. Helen Monypeny
# Futrelle, Mrs. Jacques Heath
# Futrelle, Mrs. Jacques Heath
# Osen, Mrs. Olaf Elon
# Osen, Mrs. Olaf Elon
# Giglio, Mrs. Victor
# Giglio, Mrs. Victor
# Boulos, Mrs. Joseph (Sultana)
# Boulos, Mrs. Joseph (Sultana)
# Nysten, Miss. Anna Sofia
# Nysten, Miss. Anna Sofia
# Hakkarainen, Mrs. Pekka Pietari (Elin Matilda Dolck)
# Hakkarainen, Mrs. Pekka Pietari (Elin Matilda Dolck)
# Burke, Mrs. Jeremiah
# Burke, Mrs. Jeremiah
# Andrew, Mrs. Edgardo Samuel
# Andrew, Mrs. Edgardo Samuel
# Nicholls, Mrs. Joseph Charles
# Nicholls, Mrs. Joseph Charles
# Andersson, Mrs. August Edvard ("Wennerstrom")
# Andersson, Mrs. August Edvard ("Wennerstrom")
# Ford, Miss. Robina Maggie "Ruby"
# Ford, Miss. Robina Maggie "Ruby"
# Navratil, Mrs. Michel ("Louis M Hoffman")
# Navratil, Mrs. Michel ("Louis M Hoffman")
# Byles, Officer. Thomas Roussel Davids
# Byles, Officer. Thomas Roussel Davids
# Bateman, Officer. Robert James
# Bateman, Officer. Robert James
# Pears, Mrs. Thomas (Edith Wearne)
# Pears, Mrs. Thomas (Edith Wearne)
# Meo, Mrs. Alfonzo
# Meo, Mrs. Alfonzo
# van Billiard, Mrs. Austin Blyler
# van Billiard, Mrs. Austin Blyler
# Olsen, Mrs. Ole Martin
# Olsen, Mrs. Ole Martin
# Williams, Mrs. Charles Duane
# Williams, Mrs. Charles Duane
# Gilnagh, Miss. Katherine "Katie"
# Gilnagh, Miss. Katherine "Katie"
# Corn, Mrs. Harry
# Corn, Mrs. Harry
# Smiljanic, Mrs. Mile
# Smiljanic, Mrs. Mile
# Sage, Master. Thomas Henry
# Sage, Master. Thomas Henry
# Cribb, Mrs. John Hatfield
# Cribb, Mrs. John Hatfield
# Watt, Mrs. James (Elizabeth "Bessie" Inglis Milne)
# Watt, Mrs. James (Elizabeth "Bessie" Inglis Milne)
# Bengtsson, Mrs. John Viktor
# Bengtsson, Mrs. John Viktor
# Calic, Mrs. Jovo
# Calic, Mrs. Jovo
# Panula, Master. Eino Viljami
# Panula, Master. Eino Viljami
# Goldsmith, Master. Frank John William "Frankie"
# Goldsmith, Master. Frank John William "Frankie"
# Chibnall, Mrs. (Edith Martha Bowerman)
# Chibnall, Mrs. (Edith Martha Bowerman)
# Skoog, Mrs. William (Anna Bernhardina Karlsson)
# Skoog, Mrs. William (Anna Bernhardina Karlsson)
# Baumann, Mrs. John D
# Baumann, Mrs. John D
# Ling, Mrs. Lee
# Ling, Mrs. Lee
# Van der hoef, Mrs. Wyckoff
# Van der hoef, Mrs. Wyckoff
# Rice, Master. Arthur
# Rice, Master. Arthur
# Johnson, Miss. Eleanor Ileen
# Johnson, Miss. Eleanor Ileen
# Sivola, Mrs. Antti Wilhelm
# Sivola, Mrs. Antti Wilhelm
# Smith, Mrs. James Clinch
# Smith, Mrs. James Clinch
# Klasen, Mrs. Klas Albin
# Klasen, Mrs. Klas Albin
# Lefebre, Master. Henry Forbes
# Lefebre, Master. Henry Forbes
# Isham, Miss. Ann Elizabeth
# Isham, Miss. Ann Elizabeth
# Hale, Mrs. Reginald
# Hale, Mrs. Reginald
# Leonard, Mrs. Lionel
# Leonard, Mrs. Lionel
# Sage, Miss. Constance Gladys
# Sage, Miss. Constance Gladys
# Pernot, Mrs. Rene
# Pernot, Mrs. Rene
# Asplund, Master. Clarence Gustaf Hugo
# Asplund, Master. Clarence Gustaf Hugo
# Becker, Master. Richard F
# Becker, Master. Richard F
# Kink-Heilmann, Miss. Luise Gretchen
# Kink-Heilmann, Miss. Luise Gretchen
# Rood, Mrs. Hugh Roscoe
# Rood, Mrs. Hugh Roscoe
# O'Brien, Mrs. Thomas (Johanna "Hannah" Godfrey)
# O'Brien, Mrs. Thomas (Johanna "Hannah" Godfrey)
# Romaine, Mrs. Charles Hallace ("Mrs C Rolmane")
# Romaine, Mrs. Charles Hallace ("Mrs C Rolmane")
# Bourke, Mrs. John
# Bourke, Mrs. John
# Turcin, Mrs. Stjepan
# Turcin, Mrs. Stjepan
# Pinsky, Mrs. (Rosa)
# Pinsky, Mrs. (Rosa)
# Carbines, Mrs. William
# Carbines, Mrs. William
# Andersen-Jensen, Miss. Carla Christine Nielsine
# Andersen-Jensen, Miss. Carla Christine Nielsine
# Navratil, Master. Michel M
# Navratil, Master. Michel M
# Brown, Mrs. James Joseph (Margaret Tobin)
# Brown, Mrs. James Joseph (Margaret Tobin)
# Lurette, Miss. Elise
# Lurette, Miss. Elise
# Mernagh, Mrs. Robert
# Mernagh, Mrs. Robert
# Olsen, Mrs. Karl Siegwart Andreas
# Olsen, Mrs. Karl Siegwart Andreas
# Madigan, Miss. Margaret "Maggie"
# Madigan, Miss. Margaret "Maggie"
# Yrois, Miss. Henriette ("Mrs Harbeck")
# Yrois, Miss. Henriette ("Mrs Harbeck")
# Vande Walle, Mrs. Nestor Cyriel
# Vande Walle, Mrs. Nestor Cyriel
# Sage, Mrs. Frederick
# Sage, Mrs. Frederick
# Johanson, Mrs. Jakob Alfred
# Johanson, Mrs. Jakob Alfred
# Youseff, Mrs. Gerious
# Youseff, Mrs. Gerious
# Cohen, Mrs. Gurshon "Gus"
# Cohen, Mrs. Gurshon "Gus"
# Strom, Miss. Telma Matilda
# Strom, Miss. Telma Matilda
# Backstrom, Mrs. Karl Alfred
# Backstrom, Mrs. Karl Alfred
# Albimona, Mrs. Nassef Cassem
# Albimona, Mrs. Nassef Cassem
# Carr, Miss. Helen "Ellen"
# Carr, Miss. Helen "Ellen"
# Blank, Mrs. Henry
# Blank, Mrs. Henry
# Ali, Mrs. Ahmed
# Ali, Mrs. Ahmed
# Cameron, Miss. Clear Annie
# Cameron, Miss. Clear Annie
# Perkin, Mrs. John Henry
# Perkin, Mrs. John Henry
# Givard, Mrs. Hans Kristensen
# Givard, Mrs. Hans Kristensen
# Kiernan, Mrs. Philip
# Kiernan, Mrs. Philip
# Newell, Miss. Madeleine
# Newell, Miss. Madeleine
# Honkanen, Miss. Eliina
# Honkanen, Miss. Eliina
# Jacobsohn, Mrs. Sidney Samuel
# Jacobsohn, Mrs. Sidney Samuel
# Bazzani, Miss. Albina
# Bazzani, Miss. Albina
# Harris, Mrs. Walter
# Harris, Mrs. Walter
# Sunderland, Mrs. Victor Francis
# Sunderland, Mrs. Victor Francis
# Bracken, Mrs. James H
# Bracken, Mrs. James H
# Green, Mrs. George Henry
# Green, Mrs. George Henry
# Nenkoff, Mrs. Christo
# Nenkoff, Mrs. Christo
# Hoyt, Mrs. Frederick Maxfield
# Hoyt, Mrs. Frederick Maxfield
# Berglund, Mrs. Karl Ivar Sven
# Berglund, Mrs. Karl Ivar Sven
# Mellors, Mrs. William John
# Mellors, Mrs. William John
# Lovell, Mrs. John Hall ("Henry")
# Lovell, Mrs. John Hall ("Henry")
# Fahlstrom, Mrs. Arne Jonas
# Fahlstrom, Mrs. Arne Jonas
# Lefebre, Miss. Mathilde
# Lefebre, Miss. Mathilde
# Harris, Mrs. Henry Birkhardt (Irene Wallach)
# Harris, Mrs. Henry Birkhardt (Irene Wallach)
# Larsson, Mrs. Bengt Edvin
# Larsson, Mrs. Bengt Edvin
# Sjostedt, Mrs. Ernst Adolf
# Sjostedt, Mrs. Ernst Adolf
# Asplund, Miss. Lillian Gertrud
# Asplund, Miss. Lillian Gertrud
# Leyson, Mrs. Robert William Norman
# Leyson, Mrs. Robert William Norman
# Harknett, Miss. Alice Phoebe
# Harknett, Miss. Alice Phoebe
# Hold, Mrs. Stephen
# Hold, Mrs. Stephen
# Collyer, Miss. Marjorie "Lottie"
# Collyer, Miss. Marjorie "Lottie"
# Pengelly, Mrs. Frederick William
# Pengelly, Mrs. Frederick William
# Hunt, Mrs. George Henry
# Hunt, Mrs. George Henry
# Zabour, Miss. Thamine
# Zabour, Miss. Thamine
# Murphy, Miss. Katherine "Kate"
# Murphy, Miss. Katherine "Kate"
# Coleridge, Mrs. Reginald Charles
# Coleridge, Mrs. Reginald Charles
# Maenpaa, Mrs. Matti Alexanteri
# Maenpaa, Mrs. Matti Alexanteri
# Attalah, Mrs. Sleiman
# Attalah, Mrs. Sleiman
# Minahan, Officer. William Edward
# Minahan, Officer. William Edward
# Lindahl, Miss. Agda Thorilda Viktoria
# Lindahl, Miss. Agda Thorilda Viktoria
# Hamalainen, Mrs. William (Anna)
# Hamalainen, Mrs. William (Anna)
# Beckwith, Mrs. Richard Leonard
# Beckwith, Mrs. Richard Leonard
# Carter, Officer. Ernest Courtenay
# Carter, Officer. Ernest Courtenay
# Reed, Mrs. James George
# Reed, Mrs. James George
# Strom, Mrs. Wilhelm (Elna Matilda Persson)
# Strom, Mrs. Wilhelm (Elna Matilda Persson)
# Stead, Mrs. William Thomas
# Stead, Mrs. William Thomas
# Lobb, Mrs. William Arthur
# Lobb, Mrs. William Arthur
# Rosblom, Mrs. Viktor (Helena Wilhelmina)
# Rosblom, Mrs. Viktor (Helena Wilhelmina)
# Touma, Mrs. Darwis (Hanne Youssef Razi)
# Touma, Mrs. Darwis (Hanne Youssef Razi)
# Thorne, Mrs. Gertrude Maybelle
# Thorne, Mrs. Gertrude Maybelle
# Cherry, Miss. Gladys
# Cherry, Miss. Gladys
# Ward, Miss. Anna
# Ward, Miss. Anna
# Parrish, Mrs. (Lutie Davis)
# Parrish, Mrs. (Lutie Davis)
# Smith, Mrs. Thomas
# Smith, Mrs. Thomas
# Asplund, Master. Edvin Rojj Felix
# Asplund, Master. Edvin Rojj Felix
# Taussig, Mrs. Emil
# Taussig, Mrs. Emil
# Harrison, Mrs. William
# Harrison, Mrs. William
# Henry, Miss. Delia
# Henry, Miss. Delia
# Reeves, Mrs. David
# Reeves, Mrs. David
# Panula, Mrs. Ernesti Arvid
# Panula, Mrs. Ernesti Arvid
# Persson, Mrs. Ernst Ulrik
# Persson, Mrs. Ernst Ulrik
# Graham, Mrs. William Thompson (Edith Junkins)
# Graham, Mrs. William Thompson (Edith Junkins)
# Bissette, Miss. Amelia
# Bissette, Miss. Amelia
# Cairns, Mrs. Alexander
# Cairns, Mrs. Alexander
# Tornquist, Mrs. William Henry
# Tornquist, Mrs. William Henry
# Mellinger, Mrs. (Elizabeth Anne Maidment)
# Mellinger, Mrs. (Elizabeth Anne Maidment)
# Natsch, Mrs. Charles H
# Natsch, Mrs. Charles H
# Healy, Miss. Hanora "Nora"
# Healy, Miss. Hanora "Nora"
# Andrews, Miss. Kornelia Theodosia
# Andrews, Miss. Kornelia Theodosia
# Lindblom, Miss. Augusta Charlotta
# Lindblom, Miss. Augusta Charlotta
# Parkes, Mrs. Francis "Frank"
# Parkes, Mrs. Francis "Frank"
# Rice, Master. Eric
# Rice, Master. Eric
# Abbott, Mrs. Stanton (Rosa Hunt)
# Abbott, Mrs. Stanton (Rosa Hunt)
# Duane, Mrs. Frank
# Duane, Mrs. Frank
# Olsson, Mrs. Nils Johan Goransson
# Olsson, Mrs. Nils Johan Goransson
# de Pelsmaeker, Mrs. Alfons
# de Pelsmaeker, Mrs. Alfons
# Dorking, Mrs. Edward Arthur
# Dorking, Mrs. Edward Arthur
# Smith, Mrs. Richard William
# Smith, Mrs. Richard William
# Stankovic, Mrs. Ivan
# Stankovic, Mrs. Ivan
# de Mulder, Mrs. Theodore
# de Mulder, Mrs. Theodore
# Naidenoff, Mrs. Penko
# Naidenoff, Mrs. Penko
# Hosono, Mrs. Masabumi
# Hosono, Mrs. Masabumi
# Connolly, Miss. Kate
# Connolly, Miss. Kate
# Barber, Miss. Ellen "Nellie"
# Barber, Miss. Ellen "Nellie"
# Bishop, Mrs. Dickinson H (Helen Walton)
# Bishop, Mrs. Dickinson H (Helen Walton)
# Levy, Mrs. Rene Jacques
# Levy, Mrs. Rene Jacques
# Haas, Miss. Aloisia
# Haas, Miss. Aloisia
# Mineff, Mrs. Ivan
# Mineff, Mrs. Ivan
# Lewy, Mrs. Ervin G
# Lewy, Mrs. Ervin G
# Hanna, Mrs. Mansour
# Hanna, Mrs. Mansour
# Allison, Miss. Helen Loraine
# Allison, Miss. Helen Loraine
# Saalfeld, Mrs. Adolphe
# Saalfeld, Mrs. Adolphe
# Baxter, Mrs. James (Helene DeLaudeniere Chaput)
# Baxter, Mrs. James (Helene DeLaudeniere Chaput)
# Kelly, Miss. Anna Katherine "Annie Kate"
# Kelly, Miss. Anna Katherine "Annie Kate"
# McCoy, Mrs. Bernard
# McCoy, Mrs. Bernard
# Johnson, Mrs. William Cahoone Jr
# Johnson, Mrs. William Cahoone Jr
# Keane, Miss. Nora A
# Keane, Miss. Nora A
# Williams, Mrs. Howard Hugh "Harry"
# Williams, Mrs. Howard Hugh "Harry"
# Allison, Master. Hudson Trevor
# Allison, Master. Hudson Trevor
# Fleming, Miss. Margaret
# Fleming, Miss. Margaret
# Penasco y Castellana, Mrs. Victor de Satode (Maria Josefa Perez de Soto y Vallejo)
# Penasco y Castellana, Mrs. Victor de Satode (Maria Josefa Perez de Soto y Vallejo)
# Abelson, Mrs. Samuel
# Abelson, Mrs. Samuel
# Francatelli, Miss. Laura Mabel
# Francatelli, Miss. Laura Mabel
# Hays, Miss. Margaret Bechstein
# Hays, Miss. Margaret Bechstein
# Ryerson, Miss. Emily Borie
# Ryerson, Miss. Emily Borie
# Lahtinen, Mrs. William (Anna Sylfven)
# Lahtinen, Mrs. William (Anna Sylfven)
# Hendekovic, Mrs. Ignjac
# Hendekovic, Mrs. Ignjac
# Hart, Mrs. Benjamin
# Hart, Mrs. Benjamin
# Nilsson, Miss. Helmina Josefina
# Nilsson, Miss. Helmina Josefina
# Kantor, Mrs. Sinai (Miriam Sternin)
# Kantor, Mrs. Sinai (Miriam Sternin)
# Moraweck, Officer. Ernest
# Moraweck, Officer. Ernest
# Wick, Miss. Mary Natalie
# Wick, Miss. Mary Natalie
# Spedden, Mrs. Frederic Oakley (Margaretta Corning Stone)
# Spedden, Mrs. Frederic Oakley (Margaretta Corning Stone)
# Dennis, Mrs. Samuel
# Dennis, Mrs. Samuel
# Danoff, Mrs. Yoto
# Danoff, Mrs. Yoto
# Slayter, Miss. Hilda Mary
# Slayter, Miss. Hilda Mary
# Caldwell, Mrs. Albert Francis (Sylvia Mae Harbaugh)
# Caldwell, Mrs. Albert Francis (Sylvia Mae Harbaugh)
# Sage, Mrs. George John Jr
# Sage, Mrs. George John Jr
# Young, Miss. Marie Grice
# Young, Miss. Marie Grice
# Nysveen, Mrs. Johan Hansen
# Nysveen, Mrs. Johan Hansen
# Ball, Mrs. (Ada E Hall)
# Ball, Mrs. (Ada E Hall)
# Goldsmith, Mrs. Frank John (Emily Alice Brown)
# Goldsmith, Mrs. Frank John (Emily Alice Brown)
# Hippach, Miss. Jean Gertrude
# Hippach, Miss. Jean Gertrude
# McCoy, Miss. Agnes
# McCoy, Miss. Agnes
# Partner, Mrs. Austen
# Partner, Mrs. Austen
# Graham, Mrs. George Edward
# Graham, Mrs. George Edward
# Vander Planke, Mrs. Leo Edmondus
# Vander Planke, Mrs. Leo Edmondus
# Frauenthal, Mrs. Henry William (Clara Heinsheimer)
# Frauenthal, Mrs. Henry William (Clara Heinsheimer)
# Denkoff, Mrs. Mitto
# Denkoff, Mrs. Mitto
# Pears, Mrs. Thomas Clinton
# Pears, Mrs. Thomas Clinton
# Burns, Miss. Elizabeth Margaret
# Burns, Miss. Elizabeth Margaret
# Dahl, Mrs. Karl Edwart
# Dahl, Mrs. Karl Edwart
# Blackwell, Mrs. Stephen Weart
# Blackwell, Mrs. Stephen Weart
# Navratil, Master. Edmond Roger
# Navratil, Master. Edmond Roger
# Fortune, Miss. Alice Elizabeth
# Fortune, Miss. Alice Elizabeth
# Collander, Mrs. Erik Gustaf
# Collander, Mrs. Erik Gustaf
# Sedgwick, Mrs. Charles Frederick Waddington
# Sedgwick, Mrs. Charles Frederick Waddington
# Fox, Mrs. Stanley Hubert
# Fox, Mrs. Stanley Hubert
# Brown, Miss. Amelia "Mildred"
# Brown, Miss. Amelia "Mildred"
# Smith, Miss. Marion Elsie
# Smith, Miss. Marion Elsie
# Davison, Mrs. Thomas Henry (Mary E Finck)
# Davison, Mrs. Thomas Henry (Mary E Finck)
# Coutts, Master. William Loch "William"
# Coutts, Master. William Loch "William"
# Dimic, Mrs. Jovan
# Dimic, Mrs. Jovan
# Odahl, Mrs. Nils Martin
# Odahl, Mrs. Nils Martin
# Williams-Lambert, Mrs. Fletcher Fellows
# Williams-Lambert, Mrs. Fletcher Fellows
# Elias, Mrs. Tannous
# Elias, Mrs. Tannous
# Arnold-Franchi, Mrs. Josef
# Arnold-Franchi, Mrs. Josef
# Yousif, Mrs. Wazli
# Yousif, Mrs. Wazli
# Vanden Steen, Mrs. Leo Peter
# Vanden Steen, Mrs. Leo Peter
# Bowerman, Miss. Elsie Edith
# Bowerman, Miss. Elsie Edith
# Funk, Miss. Annie Clemmer
# Funk, Miss. Annie Clemmer
# McGovern, Miss. Mary
# McGovern, Miss. Mary
# Mockler, Miss. Helen Mary "Ellie"
# Mockler, Miss. Helen Mary "Ellie"
# Skoog, Mrs. Wilhelm
# Skoog, Mrs. Wilhelm
# del Carlo, Mrs. Sebastiano
# del Carlo, Mrs. Sebastiano
# Barbara, Mrs. (Catherine David)
# Barbara, Mrs. (Catherine David)
# Asim, Mrs. Adola
# Asim, Mrs. Adola
# O'Brien, Mrs. Thomas
# O'Brien, Mrs. Thomas
# Adahl, Mrs. Mauritz Nils Martin
# Adahl, Mrs. Mauritz Nils Martin
# Warren, Mrs. Frank Manley (Anna Sophia Atkinson)
# Warren, Mrs. Frank Manley (Anna Sophia Atkinson)
# Moussa, Mrs. (Mantoura Boulos)
# Moussa, Mrs. (Mantoura Boulos)
# Jermyn, Miss. Annie
# Jermyn, Miss. Annie
# Aubart, Miss. Leontine Pauline
# Aubart, Miss. Leontine Pauline
# Harder, Mrs. George Achilles
# Harder, Mrs. George Achilles
# Wiklund, Mrs. Jakob Alfred
# Wiklund, Mrs. Jakob Alfred
# Beavan, Mrs. William Thomas
# Beavan, Mrs. William Thomas
# Ringhini, Mrs. Sante
# Ringhini, Mrs. Sante
# Palsson, Miss. Stina Viola
# Palsson, Miss. Stina Viola
# Meyer, Mrs. Edgar Joseph (Leila Saks)
# Meyer, Mrs. Edgar Joseph (Leila Saks)
# Landergren, Miss. Aurora Adelia
# Landergren, Miss. Aurora Adelia
# Widener, Mrs. Harry Elkins
# Widener, Mrs. Harry Elkins
# Betros, Mrs. Tannous
# Betros, Mrs. Tannous
# Gustafsson, Mrs. Karl Gideon
# Gustafsson, Mrs. Karl Gideon
# Bidois, Miss. Rosalie
# Bidois, Miss. Rosalie
# Nakid, Miss. Maria ("Mary")
# Nakid, Miss. Maria ("Mary")
# Tikkanen, Mrs. Juho
# Tikkanen, Mrs. Juho
# Holverson, Mrs. Alexander Oskar (Mary Aline Towner)
# Holverson, Mrs. Alexander Oskar (Mary Aline Towner)
# Plotcharsky, Mrs. Vasil
# Plotcharsky, Mrs. Vasil
# Davies, Mrs. Charles Henry
# Davies, Mrs. Charles Henry
# Goodwin, Master. Sidney Leonard
# Goodwin, Master. Sidney Leonard
# Buss, Miss. Kate
# Buss, Miss. Kate
# Sadlier, Mrs. Matthew
# Sadlier, Mrs. Matthew
# Lehmann, Miss. Bertha
# Lehmann, Miss. Bertha
# Carter, Mrs. William Ernest
# Carter, Mrs. William Ernest
# Jansson, Mrs. Carl Olof
# Jansson, Mrs. Carl Olof
# Gustafsson, Mrs. Johan Birger
# Gustafsson, Mrs. Johan Birger
# Newell, Miss. Marjorie
# Newell, Miss. Marjorie
# Sandstrom, Mrs. Hjalmar (Agnes Charlotta Bengtsson)
# Sandstrom, Mrs. Hjalmar (Agnes Charlotta Bengtsson)
# Johansson, Mrs. Erik
# Johansson, Mrs. Erik
# Olsson, Miss. Elina
# Olsson, Miss. Elina
# McKane, Mrs. Peter David
# McKane, Mrs. Peter David
# Pain, Officer. Alfred
# Pain, Officer. Alfred
# Trout, Mrs. William H (Jessie L)
# Trout, Mrs. William H (Jessie L)
# Niskanen, Mrs. Juha
# Niskanen, Mrs. Juha
# Adams, Mrs. John
# Adams, Mrs. John
# Jussila, Miss. Mari Aina
# Jussila, Miss. Mari Aina
# Hakkarainen, Mrs. Pekka Pietari
# Hakkarainen, Mrs. Pekka Pietari
# Oreskovic, Miss. Marija
# Oreskovic, Miss. Marija
# Gale, Mrs. Shadrach
# Gale, Mrs. Shadrach
# Widegren, Mrs. Carl/Charles Peter
# Widegren, Mrs. Carl/Charles Peter
# Richards, Master. William Rowe
# Richards, Master. William Rowe
# Birkeland, Mrs. Hans Martin Monsen
# Birkeland, Mrs. Hans Martin Monsen
# Lefebre, Miss. Ida
# Lefebre, Miss. Ida
# Sdycoff, Mrs. Todor
# Sdycoff, Mrs. Todor
# Hart, Mrs. Henry
# Hart, Mrs. Henry
# Minahan, Miss. Daisy E
# Minahan, Miss. Daisy E
# Cunningham, Mrs. Alfred Fleming
# Cunningham, Mrs. Alfred Fleming
# Sundman, Mrs. Johan Julian
# Sundman, Mrs. Johan Julian
# Meek, Mrs. Thomas (Annie Louise Rowley)
# Meek, Mrs. Thomas (Annie Louise Rowley)
# Drew, Mrs. James Vivian (Lulu Thorne Christian)
# Drew, Mrs. James Vivian (Lulu Thorne Christian)
# Silven, Miss. Lyyli Karoliina
# Silven, Miss. Lyyli Karoliina
# Matthews, Mrs. William John
# Matthews, Mrs. William John
# Van Impe, Miss. Catharina
# Van Impe, Miss. Catharina
# Gheorgheff, Mrs. Stanio
# Gheorgheff, Mrs. Stanio
# Charters, Mrs. David
# Charters, Mrs. David
# Zimmerman, Mrs. Leo
# Zimmerman, Mrs. Leo
# Danbom, Mrs. Ernst Gilbert (Anna Sigrid Maria Brogren)
# Danbom, Mrs. Ernst Gilbert (Anna Sigrid Maria Brogren)
# Rosblom, Mrs. Viktor Richard
# Rosblom, Mrs. Viktor Richard
# Wiseman, Mrs. Phillippe
# Wiseman, Mrs. Phillippe
# Clarke, Mrs. Charles V (Ada Maria Winfield)
# Clarke, Mrs. Charles V (Ada Maria Winfield)
# Phillips, Miss. Kate Florence ("Mrs Kate Louise Phillips Marshall")
# Phillips, Miss. Kate Florence ("Mrs Kate Louise Phillips Marshall")
# Flynn, Mrs. James
# Flynn, Mrs. James
# Pickard, Mrs. Berk (Berk Trembisky)
# Pickard, Mrs. Berk (Berk Trembisky)
# Bjornstrom-Steffansson, Mrs. Mauritz Hakan
# Bjornstrom-Steffansson, Mrs. Mauritz Hakan
# Thorneycroft, Mrs. Percival (Florence Kate White)
# Thorneycroft, Mrs. Percival (Florence Kate White)
# Louch, Mrs. Charles Alexander (Alice Adelaide Slow)
# Louch, Mrs. Charles Alexander (Alice Adelaide Slow)
# Kallio, Mrs. Nikolai Erland
# Kallio, Mrs. Nikolai Erland
# Silvey, Mrs. William Baird
# Silvey, Mrs. William Baird
# Carter, Miss. Lucile Polk
# Carter, Miss. Lucile Polk
# Ford, Miss. Doolina Margaret "Daisy"
# Ford, Miss. Doolina Margaret "Daisy"
# Richards, Mrs. Sidney (Emily Hocking)
# Richards, Mrs. Sidney (Emily Hocking)
# Fortune, Mrs. Mark
# Fortune, Mrs. Mark
# Kvillner, Mrs. Johan Henrik Johannesson
# Kvillner, Mrs. Johan Henrik Johannesson
# Hart, Mrs. Benjamin (Esther Ada Bloomfield)
# Hart, Mrs. Benjamin (Esther Ada Bloomfield)
# Hampe, Mrs. Leon
# Hampe, Mrs. Leon
# Petterson, Mrs. Johan Emil
# Petterson, Mrs. Johan Emil
# Reynaldo, Mrs. Encarnacion
# Reynaldo, Mrs. Encarnacion
# Johannesen-Bratthammer, Mrs. Bernt
# Johannesen-Bratthammer, Mrs. Bernt
# Dodge, Master. Washington
# Dodge, Master. Washington
# Mellinger, Miss. Madeleine Violet
# Mellinger, Miss. Madeleine Violet
# Seward, Mrs. Frederic Kimber
# Seward, Mrs. Frederic Kimber
# Baclini, Miss. Marie Catherine
# Baclini, Miss. Marie Catherine
# Peuchen, Officer. Arthur Godfrey
# Peuchen, Officer. Arthur Godfrey
# West, Mrs. Edwy Arthur
# West, Mrs. Edwy Arthur
# Hagland, Mrs. Ingvald Olai Olsen
# Hagland, Mrs. Ingvald Olai Olsen
# Foreman, Mrs. Benjamin Laventall
# Foreman, Mrs. Benjamin Laventall
# Goldenberg, Mrs. Samuel L
# Goldenberg, Mrs. Samuel L
# Peduzzi, Mrs. Joseph
# Peduzzi, Mrs. Joseph
# Jalsevac, Mrs. Ivan
# Jalsevac, Mrs. Ivan
# Millet, Mrs. Francis Davis
# Millet, Mrs. Francis Davis
# Kenyon, Mrs. Frederick R (Marion)
# Kenyon, Mrs. Frederick R (Marion)
# Toomey, Miss. Ellen
# Toomey, Miss. Ellen
# O'Connor, Mrs. Maurice
# O'Connor, Mrs. Maurice
# Anderson, Mrs. Harry
# Anderson, Mrs. Harry
# Morley, Mrs. William
# Morley, Mrs. William
# Gee, Mrs. Arthur H
# Gee, Mrs. Arthur H
# Milling, Mrs. Jacob Christian
# Milling, Mrs. Jacob Christian
# Maisner, Mrs. Simon
# Maisner, Mrs. Simon
# Goncalves, Mrs. Manuel Estanslas
# Goncalves, Mrs. Manuel Estanslas
# Campbell, Mrs. William
# Campbell, Mrs. William
# Smart, Mrs. John Montgomery
# Smart, Mrs. John Montgomery
# Scanlan, Mrs. James
# Scanlan, Mrs. James
# Baclini, Miss. Helene Barbara
# Baclini, Miss. Helene Barbara
# Keefe, Mrs. Arthur
# Keefe, Mrs. Arthur
# Cacic, Mrs. Luka
# Cacic, Mrs. Luka
# West, Mrs. Edwy Arthur (Ada Mary Worth)
# West, Mrs. Edwy Arthur (Ada Mary Worth)
# Jerwan, Mrs. Amin S (Marie Marthe Thuillard)
# Jerwan, Mrs. Amin S (Marie Marthe Thuillard)
# Strandberg, Miss. Ida Sofia
# Strandberg, Miss. Ida Sofia
# Clifford, Mrs. George Quincy
# Clifford, Mrs. George Quincy
# Renouf, Mrs. Peter Henry
# Renouf, Mrs. Peter Henry
# Braund, Mrs. Lewis Richard
# Braund, Mrs. Lewis Richard
# Karlsson, Mrs. Nils August
# Karlsson, Mrs. Nils August
# Hirvonen, Miss. Hildur E
# Hirvonen, Miss. Hildur E
# Goodwin, Master. Harold Victor
# Goodwin, Master. Harold Victor
# Frost, Mrs. Anthony Wood "Archie"
# Frost, Mrs. Anthony Wood "Archie"
# Rouse, Mrs. Richard Henry
# Rouse, Mrs. Richard Henry
# Turkula, Mrs. (Hedwig)
# Turkula, Mrs. (Hedwig)
# Bishop, Mrs. Dickinson H
# Bishop, Mrs. Dickinson H
# Lefebre, Miss. Jeannie
# Lefebre, Miss. Jeannie
# Hoyt, Mrs. Frederick Maxfield (Jane Anne Forby)
# Hoyt, Mrs. Frederick Maxfield (Jane Anne Forby)
# Kent, Mrs. Edward Austin
# Kent, Mrs. Edward Austin
# Somerton, Mrs. Francis William
# Somerton, Mrs. Francis William
# Coutts, Master. Eden Leslie "Neville"
# Coutts, Master. Eden Leslie "Neville"
# Hagland, Mrs. Konrad Mathias Reiersen
# Hagland, Mrs. Konrad Mathias Reiersen
# Windelov, Mrs. Einar
# Windelov, Mrs. Einar
# Molson, Mrs. Harry Markland
# Molson, Mrs. Harry Markland
# Artagaveytia, Mrs. Ramon
# Artagaveytia, Mrs. Ramon
# Stanley, Mrs. Edward Roland
# Stanley, Mrs. Edward Roland
# Yousseff, Mrs. Gerious
# Yousseff, Mrs. Gerious
# Eustis, Miss. Elizabeth Mussey
# Eustis, Miss. Elizabeth Mussey
# Shellard, Mrs. Frederick William
# Shellard, Mrs. Frederick William
# Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# Svensson, Mrs. Olof
# Svensson, Mrs. Olof
# Calic, Mrs. Petar
# Calic, Mrs. Petar
# Canavan, Miss. Mary
# Canavan, Miss. Mary
# O'Sullivan, Miss. Bridget Mary
# O'Sullivan, Miss. Bridget Mary
# Laitinen, Miss. Kristina Sofia
# Laitinen, Miss. Kristina Sofia
# Maioni, Miss. Roberta
# Maioni, Miss. Roberta
# Penasco y Castellana, Mrs. Victor de Satode
# Penasco y Castellana, Mrs. Victor de Satode
# Quick, Mrs. Frederick Charles (Jane Richards)
# Quick, Mrs. Frederick Charles (Jane Richards)
# Bradley, Mrs. George ("George Arthur Brayton")
# Bradley, Mrs. George ("George Arthur Brayton")
# Olsen, Mrs. Henry Margido
# Olsen, Mrs. Henry Margido
# Lang, Mrs. Fang
# Lang, Mrs. Fang
# Daly, Mrs. Eugene Patrick
# Daly, Mrs. Eugene Patrick
# Webber, Mrs. James
# Webber, Mrs. James
# McGough, Mrs. James Robert
# McGough, Mrs. James Robert
# Rothschild, Mrs. Martin (Elizabeth L. Barrett)
# Rothschild, Mrs. Martin (Elizabeth L. Barrett)
# Coleff, Mrs. Satio
# Coleff, Mrs. Satio
# Walker, Mrs. William Anderson
# Walker, Mrs. William Anderson
# Lemore, Mrs. (Amelia Milley)
# Lemore, Mrs. (Amelia Milley)
# Ryan, Mrs. Patrick
# Ryan, Mrs. Patrick
# Angle, Mrs. William A (Florence "Mary" Agnes Hughes)
# Angle, Mrs. William A (Florence "Mary" Agnes Hughes)
# Pavlovic, Mrs. Stefo
# Pavlovic, Mrs. Stefo
# Perreault, Miss. Anne
# Perreault, Miss. Anne
# Vovk, Mrs. Janko
# Vovk, Mrs. Janko
# Lahoud, Mrs. Sarkis
# Lahoud, Mrs. Sarkis
# Hippach, Mrs. Louis Albert (Ida Sophia Fischer)
# Hippach, Mrs. Louis Albert (Ida Sophia Fischer)
# Kassem, Mrs. Fared
# Kassem, Mrs. Fared
# Farrell, Mrs. James
# Farrell, Mrs. James
# Ridsdale, Miss. Lucy
# Ridsdale, Miss. Lucy
# Farthing, Mrs. John
# Farthing, Mrs. John
# Salonen, Mrs. Johan Werner
# Salonen, Mrs. Johan Werner
# Hocking, Mrs. Richard George
# Hocking, Mrs. Richard George
# Quick, Miss. Phyllis May
# Quick, Miss. Phyllis May
# Toufik, Mrs. Nakli
# Toufik, Mrs. Nakli
# Elias, Mrs. Joseph Jr
# Elias, Mrs. Joseph Jr
# Peter, Mrs. Catherine (Catherine Rizk)
# Peter, Mrs. Catherine (Catherine Rizk)
# Cacic, Miss. Marija
# Cacic, Miss. Marija
# Hart, Miss. Eva Miriam
# Hart, Miss. Eva Miriam
# Butt, Officer. Archibald Willingham
# Butt, Officer. Archibald Willingham
# LeRoy, Miss. Bertha
# LeRoy, Miss. Bertha
# Risien, Mrs. Samuel Beard
# Risien, Mrs. Samuel Beard
# Frolicher, Miss. Hedwig Margaritha
# Frolicher, Miss. Hedwig Margaritha
# Crosby, Miss. Harriet R
# Crosby, Miss. Harriet R
# Andersson, Miss. Ingeborg Constanzia
# Andersson, Miss. Ingeborg Constanzia
# Andersson, Miss. Sigrid Elisabeth
# Andersson, Miss. Sigrid Elisabeth
# Beane, Mrs. Edward
# Beane, Mrs. Edward
# Douglas, Mrs. Walter Donald
# Douglas, Mrs. Walter Donald
# Nicholson, Mrs. Arthur Ernest
# Nicholson, Mrs. Arthur Ernest
# Beane, Mrs. Edward (Ethel Clarke)
# Beane, Mrs. Edward (Ethel Clarke)
# Padro y Manent, Mrs. Julian
# Padro y Manent, Mrs. Julian
# Goldsmith, Mrs. Frank John
# Goldsmith, Mrs. Frank John
# Davies, Master. John Morgan Jr
# Davies, Master. John Morgan Jr
# Thayer, Mrs. John Borland Jr
# Thayer, Mrs. John Borland Jr
# Sharp, Mrs. Percival James R
# Sharp, Mrs. Percival James R
# O'Brien, Mrs. Timothy
# O'Brien, Mrs. Timothy
# Leeni, Mrs. Fahim ("Philip Zenni")
# Leeni, Mrs. Fahim ("Philip Zenni")
# Ohman, Miss. Velin
# Ohman, Miss. Velin
# Wright, Mrs. George
# Wright, Mrs. George
# Robbins, Mrs. Victor
# Robbins, Mrs. Victor
# Taussig, Mrs. Emil (Tillie Mandelbaum)
# Taussig, Mrs. Emil (Tillie Mandelbaum)
# de Messemaeker, Mrs. Guillaume Joseph (Emma)
# de Messemaeker, Mrs. Guillaume Joseph (Emma)
# Morrow, Mrs. Thomas Rowan
# Morrow, Mrs. Thomas Rowan
# Sivic, Mrs. Husein
# Sivic, Mrs. Husein
# Norman, Mrs. Robert Douglas
# Norman, Mrs. Robert Douglas
# Simmons, Mrs. John
# Simmons, Mrs. John
# Meanwell, Miss. (Marion Ogden)
# Meanwell, Miss. (Marion Ogden)
# Davies, Mrs. Alfred J
# Davies, Mrs. Alfred J
# Stoytcheff, Mrs. Ilia
# Stoytcheff, Mrs. Ilia
# Palsson, Mrs. Nils (Alma Cornelia Berglund)
# Palsson, Mrs. Nils (Alma Cornelia Berglund)
# Doharr, Mrs. Tannous
# Doharr, Mrs. Tannous
# Jonsson, Mrs. Carl
# Jonsson, Mrs. Carl
# Harris, Mrs. George
# Harris, Mrs. George
# Appleton, Mrs. Edward Dale (Charlotte Lamson)
# Appleton, Mrs. Edward Dale (Charlotte Lamson)
# Flynn, Mrs. John Irwin ("Irving")
# Flynn, Mrs. John Irwin ("Irving")
# Kelly, Miss. Mary
# Kelly, Miss. Mary
# Rush, Mrs. Alfred George John
# Rush, Mrs. Alfred George John
# Patchett, Mrs. George
# Patchett, Mrs. George
# Garside, Miss. Ethel
# Garside, Miss. Ethel
# Silvey, Mrs. William Baird (Alice Munger)
# Silvey, Mrs. William Baird (Alice Munger)
# Caram, Mrs. Joseph (Maria Elias)
# Caram, Mrs. Joseph (Maria Elias)
# Jussila, Mrs. Eiriik
# Jussila, Mrs. Eiriik
# Christy, Miss. Julie Rachel
# Christy, Miss. Julie Rachel
# Thayer, Mrs. John Borland (Marian Longstreth Morris)
# Thayer, Mrs. John Borland (Marian Longstreth Morris)
# Downton, Mrs. William James
# Downton, Mrs. William James
# Ross, Mrs. John Hugo
# Ross, Mrs. John Hugo
# Paulner, Mrs. Uscher
# Paulner, Mrs. Uscher
# Taussig, Miss. Ruth
# Taussig, Miss. Ruth
# Jarvis, Mrs. John Denzil
# Jarvis, Mrs. John Denzil
# Frolicher-Stehli, Mrs. Maxmillian
# Frolicher-Stehli, Mrs. Maxmillian
# Gilinski, Mrs. Eliezer
# Gilinski, Mrs. Eliezer
# Murdlin, Mrs. Joseph
# Murdlin, Mrs. Joseph
# Rintamaki, Mrs. Matti
# Rintamaki, Mrs. Matti
# Stephenson, Mrs. Walter Bertram (Martha Eustis)
# Stephenson, Mrs. Walter Bertram (Martha Eustis)
# Elsbury, Mrs. William James
# Elsbury, Mrs. William James
# Bourke, Miss. Mary
# Bourke, Miss. Mary
# Chapman, Mrs. John Henry
# Chapman, Mrs. John Henry
# Van Impe, Mrs. Jean Baptiste
# Van Impe, Mrs. Jean Baptiste
# Leitch, Miss. Jessie Wills
# Leitch, Miss. Jessie Wills
# Johnson, Mrs. Alfred
# Johnson, Mrs. Alfred
# Boulos, Mrs. Hanna
# Boulos, Mrs. Hanna
# Duff Gordon, Royalty. Cosmo Edmund ("Mr Morgan")
# Duff Gordon, Royalty. Cosmo Edmund ("Mr Morgan")
# Jacobsohn, Mrs. Sidney Samuel (Amy Frances Christy)
# Jacobsohn, Mrs. Sidney Samuel (Amy Frances Christy)
# Slabenoff, Mrs. Petco
# Slabenoff, Mrs. Petco
# Harrington, Mrs. Charles H
# Harrington, Mrs. Charles H
# Torber, Mrs. Ernst William
# Torber, Mrs. Ernst William
# Homer, Mrs. Harry ("Mrs E Haven")
# Homer, Mrs. Harry ("Mrs E Haven")
# Lindell, Mrs. Edvard Bengtsson
# Lindell, Mrs. Edvard Bengtsson
# Karaic, Mrs. Milan
# Karaic, Mrs. Milan
# Daniel, Mrs. Robert Williams
# Daniel, Mrs. Robert Williams
# Laroche, Mrs. Joseph (Juliette Marie Louise Lafargue)
# Laroche, Mrs. Joseph (Juliette Marie Louise Lafargue)
# Shutes, Miss. Elizabeth W
# Shutes, Miss. Elizabeth W
# Andersson, Mrs. Anders Johan (Alfrida Konstantia Brogren)
# Andersson, Mrs. Anders Johan (Alfrida Konstantia Brogren)
# Jardin, Mrs. Jose Neto
# Jardin, Mrs. Jose Neto
# Murphy, Miss. Margaret Jane
# Murphy, Miss. Margaret Jane
# Horgan, Mrs. John
# Horgan, Mrs. John
# Brocklebank, Mrs. William Alfred
# Brocklebank, Mrs. William Alfred
# Herman, Miss. Alice
# Herman, Miss. Alice
# Danbom, Mrs. Ernst Gilbert
# Danbom, Mrs. Ernst Gilbert
# Lobb, Mrs. William Arthur (Cordelia K Stanlick)
# Lobb, Mrs. William Arthur (Cordelia K Stanlick)
# Becker, Miss. Marion Louise
# Becker, Miss. Marion Louise
# Gavey, Mrs. Lawrence
# Gavey, Mrs. Lawrence
# Yasbeck, Mrs. Antoni
# Yasbeck, Mrs. Antoni
# Kimball, Mrs. Edwin Nelson Jr
# Kimball, Mrs. Edwin Nelson Jr
# Nakid, Mrs. Sahid
# Nakid, Mrs. Sahid
# Hansen, Mrs. Henry Damsgaard
# Hansen, Mrs. Henry Damsgaard
# Bowen, Mrs. David John "Dai"
# Bowen, Mrs. David John "Dai"
# Sutton, Mrs. Frederick
# Sutton, Mrs. Frederick
# Kirkland, Officer. Charles Leonard
# Kirkland, Officer. Charles Leonard
# Longley, Miss. Gretchen Fiske
# Longley, Miss. Gretchen Fiske
# Bostandyeff, Mrs. Guentcho
# Bostandyeff, Mrs. Guentcho
# O'Connell, Mrs. Patrick D
# O'Connell, Mrs. Patrick D
# Barkworth, Mrs. Algernon Henry Wilson
# Barkworth, Mrs. Algernon Henry Wilson
# Lundahl, Mrs. Johan Svensson
# Lundahl, Mrs. Johan Svensson
# Stahelin-Maeglin, Officer. Max
# Stahelin-Maeglin, Officer. Max
# Parr, Mrs. William Henry Marsh
# Parr, Mrs. William Henry Marsh
# Skoog, Miss. Mabel
# Skoog, Miss. Mabel
# Davis, Miss. Mary
# Davis, Miss. Mary
# Leinonen, Mrs. Antti Gustaf
# Leinonen, Mrs. Antti Gustaf
# Collyer, Mrs. Harvey
# Collyer, Mrs. Harvey
# Panula, Mrs. Juha (Maria Emilia Ojala)
# Panula, Mrs. Juha (Maria Emilia Ojala)
# Thorneycroft, Mrs. Percival
# Thorneycroft, Mrs. Percival
# Jensen, Mrs. Hans Peder
# Jensen, Mrs. Hans Peder
# Sagesser, Miss. Emma
# Sagesser, Miss. Emma
# Skoog, Miss. Margit Elizabeth
# Skoog, Miss. Margit Elizabeth
# Foo, Mrs. Choong
# Foo, Mrs. Choong
# Baclini, Miss. Eugenie
# Baclini, Miss. Eugenie
# Harper, Mrs. Henry Sleeper
# Harper, Mrs. Henry Sleeper
# Cor, Mrs. Liudevit
# Cor, Mrs. Liudevit
# Simonius-Blumer, Officer. Oberst Alfons
# Simonius-Blumer, Officer. Oberst Alfons
# Willey, Mrs. Edward
# Willey, Mrs. Edward
# Stanley, Miss. Amy Zillah Elsie
# Stanley, Miss. Amy Zillah Elsie
# Mitkoff, Mrs. Mito
# Mitkoff, Mrs. Mito
# Doling, Miss. Elsie
# Doling, Miss. Elsie
# Kalvik, Mrs. Johannes Halvorsen
# Kalvik, Mrs. Johannes Halvorsen
# O'Leary, Miss. Hanora "Norah"
# O'Leary, Miss. Hanora "Norah"
# Hegarty, Miss. Hanora "Nora"
# Hegarty, Miss. Hanora "Nora"
# Hickman, Mrs. Leonard Mark
# Hickman, Mrs. Leonard Mark
# Radeff, Mrs. Alexander
# Radeff, Mrs. Alexander
# Bourke, Mrs. John (Catherine)
# Bourke, Mrs. John (Catherine)
# Eitemiller, Mrs. George Floyd
# Eitemiller, Mrs. George Floyd
# Newell, Mrs. Arthur Webster
# Newell, Mrs. Arthur Webster
# Frauenthal, Officer. Henry William
# Frauenthal, Officer. Henry William
# Badt, Mrs. Mohamed
# Badt, Mrs. Mohamed
# Colley, Mrs. Edward Pomeroy
# Colley, Mrs. Edward Pomeroy
# Coleff, Mrs. Peju
# Coleff, Mrs. Peju
# Lindqvist, Mrs. Eino William
# Lindqvist, Mrs. Eino William
# Hickman, Mrs. Lewis
# Hickman, Mrs. Lewis
# Butler, Mrs. Reginald Fenton
# Butler, Mrs. Reginald Fenton
# Rommetvedt, Mrs. Knud Paust
# Rommetvedt, Mrs. Knud Paust
# Cook, Mrs. Jacob
# Cook, Mrs. Jacob
# Taylor, Mrs. Elmer Zebley (Juliet Cummins Wright)
# Taylor, Mrs. Elmer Zebley (Juliet Cummins Wright)
# Brown, Mrs. Thomas William Solomon (Elizabeth Catherine Ford)
# Brown, Mrs. Thomas William Solomon (Elizabeth Catherine Ford)
# Davidson, Mrs. Thornton
# Davidson, Mrs. Thornton
# Mitchell, Mrs. Henry Michael
# Mitchell, Mrs. Henry Michael
# Wilhelms, Mrs. Charles
# Wilhelms, Mrs. Charles
# Watson, Mrs. Ennis Hastings
# Watson, Mrs. Ennis Hastings
# Edvardsson, Mrs. Gustaf Hjalmar
# Edvardsson, Mrs. Gustaf Hjalmar
# Sawyer, Mrs. Frederick Charles
# Sawyer, Mrs. Frederick Charles
# Turja, Miss. Anna Sofia
# Turja, Miss. Anna Sofia
# Goodwin, Mrs. Frederick (Augusta Tyler)
# Goodwin, Mrs. Frederick (Augusta Tyler)
# Cardeza, Mrs. Thomas Drake Martinez
# Cardeza, Mrs. Thomas Drake Martinez
# Peters, Miss. Katie
# Peters, Miss. Katie
# Hassab, Mrs. Hammad
# Hassab, Mrs. Hammad
# Olsvigen, Mrs. Thor Anderson
# Olsvigen, Mrs. Thor Anderson
# Goodwin, Mrs. Charles Edward
# Goodwin, Mrs. Charles Edward
# Brown, Mrs. Thomas William Solomon
# Brown, Mrs. Thomas William Solomon
# Laroche, Mrs. Joseph Philippe Lemercier
# Laroche, Mrs. Joseph Philippe Lemercier
# Panula, Mrs. Jaako Arnold
# Panula, Mrs. Jaako Arnold
# Dakic, Mrs. Branko
# Dakic, Mrs. Branko
# Fischer, Mrs. Eberhard Thelander
# Fischer, Mrs. Eberhard Thelander
# Madill, Miss. Georgette Alexandra
# Madill, Miss. Georgette Alexandra
# Dick, Mrs. Albert Adrian
# Dick, Mrs. Albert Adrian
# Karun, Miss. Manca
# Karun, Miss. Manca
# Lam, Mrs. Ali
# Lam, Mrs. Ali
# Saad, Mrs. Khalil
# Saad, Mrs. Khalil
# Weir, Officer. John
# Weir, Officer. John
# Chapman, Mrs. Charles Henry
# Chapman, Mrs. Charles Henry
# Kelly, Mrs. James
# Kelly, Mrs. James
# Mullens, Miss. Katherine "Katie"
# Mullens, Miss. Katherine "Katie"
# Thayer, Mrs. John Borland
# Thayer, Mrs. John Borland
# Humblen, Mrs. Adolf Mathias Nicolai Olsen
# Humblen, Mrs. Adolf Mathias Nicolai Olsen
# Astor, Mrs. John Jacob (Madeleine Talmadge Force)
# Astor, Mrs. John Jacob (Madeleine Talmadge Force)
# Silverthorne, Mrs. Spencer Victor
# Silverthorne, Mrs. Spencer Victor
# Barbara, Miss. Saiide
# Barbara, Miss. Saiide
# Gallagher, Mrs. Martin
# Gallagher, Mrs. Martin
# Hansen, Mrs. Henrik Juul
# Hansen, Mrs. Henrik Juul
# Morley, Mrs. Henry Samuel ("Mrs Henry Marshall")
# Morley, Mrs. Henry Samuel ("Mrs Henry Marshall")
# Kelly, Mrs. Florence "Fannie"
# Kelly, Mrs. Florence "Fannie"
# Calderhead, Mrs. Edward Pennington
# Calderhead, Mrs. Edward Pennington
# Cleaver, Miss. Alice
# Cleaver, Miss. Alice
# Moubarek, Master. Halim Gonios ("William George")
# Moubarek, Master. Halim Gonios ("William George")
# Mayne, Miss. Berthe Antonine ("Mrs de Villiers")
# Mayne, Miss. Berthe Antonine ("Mrs de Villiers")
# Klaber, Mrs. Herman
# Klaber, Mrs. Herman
# Taylor, Mrs. Elmer Zebley
# Taylor, Mrs. Elmer Zebley
# Larsson, Mrs. August Viktor
# Larsson, Mrs. August Viktor
# Greenberg, Mrs. Samuel
# Greenberg, Mrs. Samuel
# Soholt, Mrs. Peter Andreas Lauritz Andersen
# Soholt, Mrs. Peter Andreas Lauritz Andersen
# Endres, Miss. Caroline Louise
# Endres, Miss. Caroline Louise
# Troutt, Miss. Edwina Celia "Winnie"
# Troutt, Miss. Edwina Celia "Winnie"
# McEvoy, Mrs. Michael
# McEvoy, Mrs. Michael
# Johnson, Mrs. Malkolm Joackim
# Johnson, Mrs. Malkolm Joackim
# Harper, Miss. Annie Jessie "Nina"
# Harper, Miss. Annie Jessie "Nina"
# Jensen, Mrs. Svend Lauritz
# Jensen, Mrs. Svend Lauritz
# Gillespie, Mrs. William Henry
# Gillespie, Mrs. William Henry
# Hodges, Mrs. Henry Price
# Hodges, Mrs. Henry Price
# Chambers, Mrs. Norman Campbell
# Chambers, Mrs. Norman Campbell
# Oreskovic, Mrs. Luka
# Oreskovic, Mrs. Luka
# Renouf, Mrs. Peter Henry (Lillian Jefferys)
# Renouf, Mrs. Peter Henry (Lillian Jefferys)
# Mannion, Miss. Margareth
# Mannion, Miss. Margareth
# Bryhl, Mrs. Kurt Arnold Gottfrid
# Bryhl, Mrs. Kurt Arnold Gottfrid
# Ilmakangas, Miss. Pieta Sofia
# Ilmakangas, Miss. Pieta Sofia
# Allen, Miss. Elisabeth Walton
# Allen, Miss. Elisabeth Walton
# Hassan, Mrs. Houssein G N
# Hassan, Mrs. Houssein G N
# Knight, Mrs. Robert J
# Knight, Mrs. Robert J
# Berriman, Mrs. William John
# Berriman, Mrs. William John
# Troupiansky, Mrs. Moses Aaron
# Troupiansky, Mrs. Moses Aaron
# Williams, Mrs. Leslie
# Williams, Mrs. Leslie
# Ford, Mrs. Edward (Margaret Ann Watson)
# Ford, Mrs. Edward (Margaret Ann Watson)
# Lesurer, Mrs. Gustave J
# Lesurer, Mrs. Gustave J
# Ivanoff, Mrs. Kanio
# Ivanoff, Mrs. Kanio
# Nankoff, Mrs. Minko
# Nankoff, Mrs. Minko
# Hawksford, Mrs. Walter James
# Hawksford, Mrs. Walter James
# Cavendish, Mrs. Tyrell William
# Cavendish, Mrs. Tyrell William
# Ryerson, Miss. Susan Parker "Suzette"
# Ryerson, Miss. Susan Parker "Suzette"
# McNamee, Mrs. Neal
# McNamee, Mrs. Neal
# Stranden, Mrs. Juho
# Stranden, Mrs. Juho
# Crosby, Officer. Edward Gifford
# Crosby, Officer. Edward Gifford
# Abbott, Mrs. Rossmore Edward
# Abbott, Mrs. Rossmore Edward
# Sinkkonen, Miss. Anna
# Sinkkonen, Miss. Anna
# Marvin, Mrs. Daniel Warner
# Marvin, Mrs. Daniel Warner
# Connaghton, Mrs. Michael
# Connaghton, Mrs. Michael
# Wells, Miss. Joan
# Wells, Miss. Joan
# Moor, Master. Meier
# Moor, Master. Meier
# Vande Velde, Mrs. Johannes Joseph
# Vande Velde, Mrs. Johannes Joseph
# Jonkoff, Mrs. Lalio
# Jonkoff, Mrs. Lalio
# Herman, Mrs. Samuel (Jane Laver)
# Herman, Mrs. Samuel (Jane Laver)
# Hamalainen, Master. Viljo
# Hamalainen, Master. Viljo
# Carlsson, Mrs. August Sigfrid
# Carlsson, Mrs. August Sigfrid
# Bailey, Mrs. Percy Andrew
# Bailey, Mrs. Percy Andrew
# Theobald, Mrs. Thomas Leonard
# Theobald, Mrs. Thomas Leonard
# Garfirth, Mrs. John
# Garfirth, Mrs. John
# Nirva, Mrs. Iisakki Antino Aijo
# Nirva, Mrs. Iisakki Antino Aijo
# Barah, Mrs. Hanna Assi
# Barah, Mrs. Hanna Assi
# Carter, Mrs. William Ernest (Lucile Polk)
# Carter, Mrs. William Ernest (Lucile Polk)
# Eklund, Mrs. Hans Linus
# Eklund, Mrs. Hans Linus
# Hogeboom, Mrs. John C (Anna Andrews)
# Hogeboom, Mrs. John C (Anna Andrews)
# Brewe, Officer. Arthur Jackson
# Brewe, Officer. Arthur Jackson
# Mangan, Miss. Mary
# Mangan, Miss. Mary
# Moran, Mrs. Daniel J
# Moran, Mrs. Daniel J
# Gronnestad, Mrs. Daniel Danielsen
# Gronnestad, Mrs. Daniel Danielsen
# Lievens, Mrs. Rene Aime
# Lievens, Mrs. Rene Aime
# Jensen, Mrs. Niels Peder
# Jensen, Mrs. Niels Peder
# Mack, Mrs. (Mary)
# Mack, Mrs. (Mary)
# Elias, Mrs. Dibo
# Elias, Mrs. Dibo
# Hocking, Mrs. Elizabeth (Eliza Needs)
# Hocking, Mrs. Elizabeth (Eliza Needs)
# Myhrman, Mrs. Pehr Fabian Oliver Malkolm
# Myhrman, Mrs. Pehr Fabian Oliver Malkolm
# Tobin, Mrs. Roger
# Tobin, Mrs. Roger
# Emanuel, Miss. Virginia Ethel
# Emanuel, Miss. Virginia Ethel
# Kilgannon, Mrs. Thomas J
# Kilgannon, Mrs. Thomas J
# Robert, Mrs. Edward Scott (Elisabeth Walton McMillan)
# Robert, Mrs. Edward Scott (Elisabeth Walton McMillan)
# Ayoub, Miss. Banoura
# Ayoub, Miss. Banoura
# Dick, Mrs. Albert Adrian (Vera Gillespie)
# Dick, Mrs. Albert Adrian (Vera Gillespie)
# Long, Mrs. Milton Clyde
# Long, Mrs. Milton Clyde
# Johnston, Mrs. Andrew G
# Johnston, Mrs. Andrew G
# Ali, Mrs. William
# Ali, Mrs. William
# Harmer, Mrs. Abraham (David Lishin)
# Harmer, Mrs. Abraham (David Lishin)
# Sjoblom, Miss. Anna Sofia
# Sjoblom, Miss. Anna Sofia
# Rice, Master. George Hugh
# Rice, Master. George Hugh
# Dean, Master. Bertram Vere
# Dean, Master. Bertram Vere
# Guggenheim, Mrs. Benjamin
# Guggenheim, Mrs. Benjamin
# Keane, Mrs. Andrew "Andy"
# Keane, Mrs. Andrew "Andy"
# Gaskell, Mrs. Alfred
# Gaskell, Mrs. Alfred
# Sage, Miss. Stella Anna
# Sage, Miss. Stella Anna
# Hoyt, Mrs. William Fisher
# Hoyt, Mrs. William Fisher
# Dantcheff, Mrs. Ristiu
# Dantcheff, Mrs. Ristiu
# Otter, Mrs. Richard
# Otter, Mrs. Richard
# Leader, Officer. Alice (Farnham)
# Leader, Officer. Alice (Farnham)
# Osman, Mrs. Mara
# Osman, Mrs. Mara
# Ibrahim Shawah, Mrs. Yousseff
# Ibrahim Shawah, Mrs. Yousseff
# Van Impe, Mrs. Jean Baptiste (Rosalie Paula Govaert)
# Van Impe, Mrs. Jean Baptiste (Rosalie Paula Govaert)
# Ponesell, Mrs. Martin
# Ponesell, Mrs. Martin
# Collyer, Mrs. Harvey (Charlotte Annie Tate)
# Collyer, Mrs. Harvey (Charlotte Annie Tate)
# Carter, Master. William Thornton II
# Carter, Master. William Thornton II
# Thomas, Master. Assad Alexander
# Thomas, Master. Assad Alexander
# Hedman, Mrs. Oskar Arvid
# Hedman, Mrs. Oskar Arvid
# Johansson, Mrs. Karl Johan
# Johansson, Mrs. Karl Johan
# Andrews, Mrs. Thomas Jr
# Andrews, Mrs. Thomas Jr
# Pettersson, Miss. Ellen Natalia
# Pettersson, Miss. Ellen Natalia
# Meyer, Mrs. August
# Meyer, Mrs. August
# Chambers, Mrs. Norman Campbell (Bertha Griggs)
# Chambers, Mrs. Norman Campbell (Bertha Griggs)
# Alexander, Mrs. William
# Alexander, Mrs. William
# Lester, Mrs. James
# Lester, Mrs. James
# Slemen, Mrs. Richard James
# Slemen, Mrs. Richard James
# Andersson, Miss. Ebba Iris Alfrida
# Andersson, Miss. Ebba Iris Alfrida
# Tomlin, Mrs. Ernest Portage
# Tomlin, Mrs. Ernest Portage
# Fry, Mrs. Richard
# Fry, Mrs. Richard
# Heininen, Miss. Wendla Maria
# Heininen, Miss. Wendla Maria
# Mallet, Mrs. Albert
# Mallet, Mrs. Albert
# Holm, Mrs. John Fredrik Alexander
# Holm, Mrs. John Fredrik Alexander
# Skoog, Master. Karl Thorsten
# Skoog, Master. Karl Thorsten
# Hays, Mrs. Charles Melville (Clara Jennings Gregg)
# Hays, Mrs. Charles Melville (Clara Jennings Gregg)
# Lulic, Mrs. Nikola
# Lulic, Mrs. Nikola
# Reuchlin, Royalty. John George
# Reuchlin, Royalty. John George
# Moor, Mrs. (Beila)
# Moor, Mrs. (Beila)
# Panula, Master. Urho Abraham
# Panula, Master. Urho Abraham
# Flynn, Mrs. John
# Flynn, Mrs. John
# Lam, Mrs. Len
# Lam, Mrs. Len
# Mallet, Master. Andre
# Mallet, Master. Andre
# McCormack, Mrs. Thomas Joseph
# McCormack, Mrs. Thomas Joseph
# Stone, Mrs. George Nelson (Martha Evelyn)
# Stone, Mrs. George Nelson (Martha Evelyn)
# Yasbeck, Mrs. Antoni (Selini Alexander)
# Yasbeck, Mrs. Antoni (Selini Alexander)
# Richards, Master. George Sibley
# Richards, Master. George Sibley
# Saad, Mrs. Amin
# Saad, Mrs. Amin
# Augustsson, Mrs. Albert
# Augustsson, Mrs. Albert
# Allum, Mrs. Owen George
# Allum, Mrs. Owen George
# Compton, Miss. Sara Rebecca
# Compton, Miss. Sara Rebecca
# Pasic, Mrs. Jakob
# Pasic, Mrs. Jakob
# Sirota, Mrs. Maurice
# Sirota, Mrs. Maurice
# Chip, Mrs. Chang
# Chip, Mrs. Chang
# Marechal, Mrs. Pierre
# Marechal, Mrs. Pierre
# Alhomaki, Mrs. Ilmari Rudolf
# Alhomaki, Mrs. Ilmari Rudolf
# Mudd, Mrs. Thomas Charles
# Mudd, Mrs. Thomas Charles
# Serepeca, Miss. Augusta
# Serepeca, Miss. Augusta
# Lemberopolous, Mrs. Peter L
# Lemberopolous, Mrs. Peter L
# Culumovic, Mrs. Jeso
# Culumovic, Mrs. Jeso
# ...
#  'Ibrahim Shawah, Mr. Yousseff',
#  'Icard, Miss. Amelie',
#  'Ilett, Miss. Bertha',
#  'Ilmakangas, Miss. Pieta Sofia',
#  'Isham, Miss. Ann Elizabeth',
#  'Ivanoff, Mr. Kanio',
#  'Jacobsohn, Mr. Sidney Samuel',
#  'Jacobsohn, Mrs. Sidney Samuel (Amy Frances Christy)',
#  'Jalsevac, Mr. Ivan',
#  'Jansson, Mr. Carl Olof',
#  'Jardin, Mr. Jose Neto',
#  'Jarvis, Mr. John Denzil',
#  'Jenkin, Mr. Stephen Curnow',
#  'Jensen, Mr. Hans Peder',
#  'Jensen, Mr. Niels Peder',
#  'Jensen, Mr. Svend Lauritz',
#  'Jermyn, Miss. Annie',
#  'Jerwan, Mrs. Amin S (Marie Marthe Thuillard)',
#  'Johannesen-Bratthammer, Mr. Bernt',
#  'Johanson, Mr. Jakob Alfred',
#  'Johansson, Mr. Erik',
#  'Johansson, Mr. Gustaf Joel',
#  'Johansson, Mr. Karl Johan',
#  'Johnson, Master. Harold Theodor',
#  'Johnson, Miss. Eleanor Ileen',
#  'Johnson, Mr. Alfred',
#  'Johnson, Mr. Malkolm Joackim',
#  'Johnson, Mr. William Cahoone Jr',
#  'Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)',
#  'Johnston, Miss. Catherine Helen "Carrie"',
#  'Johnston, Mr. Andrew G',
#  'Jonkoff, Mr. Lalio',
#  'Jonsson, Mr. Carl',
#  'Jussila, Miss. Katriina',
#  'Jussila, Miss. Mari Aina',
#  'Jussila, Mr. Eiriik',
#  'Kallio, Mr. Nikolai Erland',
#  'Kalvik, Mr. Johannes Halvorsen',
#  'Kantor, Mr. Sinai',
#  'Kantor, Mrs. Sinai (Miriam Sternin)',
#  'Karaic, Mr. Milan',
#  'Karlsson, Mr. Nils August',
#  'Karun, Miss. Manca',
#  'Kassem, Mr. Fared',
#  'Keane, Miss. Nora A',
#  'Keane, Mr. Andrew "Andy"',
#  'Keefe, Mr. Arthur',
#  'Kelly, Miss. Anna Katherine "Annie Kate"',
#  'Kelly, Miss. Mary',
#  'Kelly, Mr. James',
#  'Kelly, Mrs. Florence "Fannie"',
#  'Kent, Mr. Edward Austin',
#  'Kenyon, Mrs. Frederick R (Marion)',
#  'Kiernan, Mr. Philip',
#  'Kilgannon, Mr. Thomas J',
#  'Kimball, Mr. Edwin Nelson Jr',
#  'Kink, Mr. Vincenz',
#  'Kink-Heilmann, Miss. Luise Gretchen',
#  'Kirkland, Rev. Charles Leonard',
#  'Klaber, Mr. Herman',
#  'Klasen, Mr. Klas Albin',
#  'Knight, Mr. Robert J',
#  'Kraeff, Mr. Theodor',
#  'Kvillner, Mr. Johan Henrik Johannesson',
#  'Lahoud, Mr. Sarkis',
#  'Lahtinen, Mrs. William (Anna Sylfven)',
#  'Laitinen, Miss. Kristina Sofia',
#  'Laleff, Mr. Kristo',
#  'Lam, Mr. Ali',
#  'Lam, Mr. Len',
#  'Landergren, Miss. Aurora Adelia',
#  'Lang, Mr. Fang',
#  'Laroche, Miss. Simonne Marie Anne Andree',
#  'Laroche, Mr. Joseph Philippe Lemercier',
#  'Laroche, Mrs. Joseph (Juliette Marie Louise Lafargue)',
#  'Larsson, Mr. August Viktor',
#  'Larsson, Mr. Bengt Edvin',
#  'LeRoy, Miss. Bertha',
#  'Leader, Dr. Alice (Farnham)',
#  'Leeni, Mr. Fahim ("Philip Zenni")',
#  'Lefebre, Master. Henry Forbes',
#  'Lefebre, Miss. Ida',
#  'Lefebre, Miss. Jeannie',
#  'Lefebre, Miss. Mathilde',
#  'Lehmann, Miss. Bertha',
#  'Leinonen, Mr. Antti Gustaf',
#  'Leitch, Miss. Jessie Wills',
#  'Lemberopolous, Mr. Peter L',
#  'Lemore, Mrs. (Amelia Milley)',
#  'Lennon, Mr. Denis',
#  'Leonard, Mr. Lionel',
#  'Lester, Mr. James',
#  'Lesurer, Mr. Gustave J',
#  'Levy, Mr. Rene Jacques',
#  'Lewy, Mr. Ervin G',
#  'Leyson, Mr. Robert William Norman',
#  'Lievens, Mr. Rene Aime',
#  'Lindahl, Miss. Agda Thorilda Viktoria',
#  'Lindblom, Miss. Augusta Charlotta',
#  'Lindell, Mr. Edvard Bengtsson',
#  'Lindqvist, Mr. Eino William',
#  'Lines, Miss. Mary Conover',
#  'Ling, Mr. Lee',
#  'Lobb, Mr. William Arthur',
#  'Lobb, Mrs. William Arthur (Cordelia K Stanlick)',
#  'Long, Mr. Milton Clyde',
#  'Longley, Miss. Gretchen Fiske',
#  'Louch, Mrs. Charles Alexander (Alice Adelaide Slow)',
#  'Lovell, Mr. John Hall ("Henry")',
#  'Lulic, Mr. Nikola',
#  'Lundahl, Mr. Johan Svensson',
#  'Lurette, Miss. Elise',
#  'Mack, Mrs. (Mary)',
#  'Madigan, Miss. Margaret "Maggie"',
#  'Madill, Miss. Georgette Alexandra',
#  'Madsen, Mr. Fridtjof Arne',
#  'Maenpaa, Mr. Matti Alexanteri',
#  'Maioni, Miss. Roberta',
#  'Maisner, Mr. Simon',
#  'Mallet, Master. Andre',
#  'Mallet, Mr. Albert',
#  'Mamee, Mr. Hanna',
#  'Mangan, Miss. Mary',
#  'Mannion, Miss. Margareth',
#  'Marechal, Mr. Pierre',
#  'Markoff, Mr. Marin',
#  'Markun, Mr. Johann',
#  'Marvin, Mr. Daniel Warner',
#  'Masselmani, Mrs. Fatima',
#  'Matthews, Mr. William John',
#  'Mayne, Mlle. Berthe Antonine ("Mrs de Villiers")',
#  'McCarthy, Mr. Timothy J',
#  'McCormack, Mr. Thomas Joseph',
#  'McCoy, Miss. Agnes',
#  'McCoy, Mr. Bernard',
#  'McDermott, Miss. Brigdet Delia',
#  'McEvoy, Mr. Michael',
#  'McGough, Mr. James Robert',
#  'McGovern, Miss. Mary',
#  'McGowan, Miss. Anna "Annie"',
#  'McKane, Mr. Peter David',
#  'McMahon, Mr. Martin',
#  'McNamee, Mr. Neal',
#  'Meanwell, Miss. (Marion Ogden)',
#  'Meek, Mrs. Thomas (Annie Louise Rowley)',
#  'Mellinger, Miss. Madeleine Violet',
#  'Mellinger, Mrs. (Elizabeth Anne Maidment)',
#  'Mellors, Mr. William John',
#  'Meo, Mr. Alfonzo',
#  'Mernagh, Mr. Robert',
#  'Meyer, Mr. August',
#  'Meyer, Mr. Edgar Joseph',
#  'Meyer, Mrs. Edgar Joseph (Leila Saks)',
#  'Millet, Mr. Francis Davis',
#  'Milling, Mr. Jacob Christian',
#  'Minahan, Dr. William Edward',
#  'Minahan, Miss. Daisy E',
#  'Mineff, Mr. Ivan',
#  'Mionoff, Mr. Stoytcho',
#  'Mitchell, Mr. Henry Michael',
#  'Mitkoff, Mr. Mito',
#  'Mockler, Miss. Helen Mary "Ellie"',
#  'Moen, Mr. Sigurd Hansen',
#  'Molson, Mr. Harry Markland',
#  'Montvila, Rev. Juozas',
#  'Moor, Master. Meier',
#  'Moor, Mrs. (Beila)',
#  'Moore, Mr. Leonard Charles',
#  'Moran, Miss. Bertha',
#  'Moran, Mr. Daniel J',
#  'Moran, Mr. James',
#  'Moraweck, Dr. Ernest',
#  'Morley, Mr. Henry Samuel ("Mr Henry Marshall")',
#  'Morley, Mr. William',
#  'Morrow, Mr. Thomas Rowan',
#  'Moss, Mr. Albert Johan',
#  'Moubarek, Master. Gerios',
#  'Moubarek, Master. Halim Gonios ("William George")',
#  'Moussa, Mrs. (Mantoura Boulos)',
#  'Moutal, Mr. Rahamin Haim',
#  'Mudd, Mr. Thomas Charles',
#  'Mullens, Miss. Katherine "Katie"',
#  'Murdlin, Mr. Joseph',
#  'Murphy, Miss. Katherine "Kate"',
#  'Murphy, Miss. Margaret Jane',
#  'Myhrman, Mr. Pehr Fabian Oliver Malkolm',
#  'Naidenoff, Mr. Penko',
#  'Najib, Miss. Adele Kiamie "Jane"',
#  'Nakid, Miss. Maria ("Mary")',
#  'Nakid, Mr. Sahid',
#  'Nankoff, Mr. Minko',
#  'Nasser, Mr. Nicholas',
#  'Nasser, Mrs. Nicholas (Adele Achem)',
#  'Natsch, Mr. Charles H',
#  'Navratil, Master. Edmond Roger',
#  'Navratil, Master. Michel M',
#  'Navratil, Mr. Michel ("Louis M Hoffman")',
#  'Nenkoff, Mr. Christo',
#  'Newell, Miss. Madeleine',
#  'Newell, Miss. Marjorie',
#  'Newell, Mr. Arthur Webster',
#  'Newsom, Miss. Helen Monypeny',
#  'Nicholls, Mr. Joseph Charles',
#  'Nicholson, Mr. Arthur Ernest',
#  'Nicola-Yarred, Master. Elias',
#  'Nicola-Yarred, Miss. Jamila',
#  'Nilsson, Miss. Helmina Josefina',
#  'Nirva, Mr. Iisakki Antino Aijo',
#  'Niskanen, Mr. Juha',
#  'Norman, Mr. Robert Douglas',
#  'Nosworthy, Mr. Richard Cater',
#  'Novel, Mr. Mansouer',
#  'Nye, Mrs. (Elizabeth Ramell)',
#  'Nysten, Miss. Anna Sofia',
#  'Nysveen, Mr. Johan Hansen',
#  "O'Brien, Mr. Thomas",
#  "O'Brien, Mr. Timothy",
#  'O\'Brien, Mrs. Thomas (Johanna "Hannah" Godfrey)',
#  "O'Connell, Mr. Patrick D",
#  "O'Connor, Mr. Maurice",
#  "O'Driscoll, Miss. Bridget",
#  'O\'Dwyer, Miss. Ellen "Nellie"',
#  'O\'Leary, Miss. Hanora "Norah"',
#  "O'Sullivan, Miss. Bridget Mary",
#  'Odahl, Mr. Nils Martin',
#  'Ohman, Miss. Velin',
#  'Olsen, Mr. Henry Margido',
#  'Olsen, Mr. Karl Siegwart Andreas',
#  'Olsen, Mr. Ole Martin',
#  'Olsson, Miss. Elina',
#  'Olsson, Mr. Nils Johan Goransson',
#  'Olsvigen, Mr. Thor Anderson',
#  'Oreskovic, Miss. Marija',
#  'Oreskovic, Mr. Luka',
#  'Osen, Mr. Olaf Elon',
#  'Osman, Mrs. Mara',
#  'Ostby, Mr. Engelhart Cornelius',
#  'Otter, Mr. Richard',
#  'Padro y Manent, Mr. Julian',
#  'Pain, Dr. Alfred',
#  'Palsson, Master. Gosta Leonard',
#  'Palsson, Miss. Stina Viola',
#  'Palsson, Miss. Torborg Danira',
#  'Palsson, Mrs. Nils (Alma Cornelia Berglund)',
#  'Panula, Master. Eino Viljami',
#  'Panula, Master. Juha Niilo',
#  'Panula, Master. Urho Abraham',
#  'Panula, Mr. Ernesti Arvid',
#  'Panula, Mr. Jaako Arnold',
#  'Panula, Mrs. Juha (Maria Emilia Ojala)',
#  'Parkes, Mr. Francis "Frank"',
#  'Parr, Mr. William Henry Marsh',
#  'Parrish, Mrs. (Lutie Davis)',
#  'Partner, Mr. Austen',
#  'Pasic, Mr. Jakob',
#  'Patchett, Mr. George',
#  'Paulner, Mr. Uscher',
#  'Pavlovic, Mr. Stefo',
#  'Pears, Mr. Thomas Clinton',
#  'Pears, Mrs. Thomas (Edith Wearne)',
#  'Peduzzi, Mr. Joseph',
#  'Pekoniemi, Mr. Edvard',
#  'Penasco y Castellana, Mr. Victor de Satode',
#  'Penasco y Castellana, Mrs. Victor de Satode (Maria Josefa Perez de Soto y Vallejo)',
#  'Pengelly, Mr. Frederick William',
#  'Perkin, Mr. John Henry',
#  'Pernot, Mr. Rene',
#  'Perreault, Miss. Anne',
#  'Persson, Mr. Ernst Ulrik',
#  'Peter, Miss. Anna',
#  'Peter, Mrs. Catherine (Catherine Rizk)',
#  'Peters, Miss. Katie',
#  'Petranec, Miss. Matilda',
#  'Petroff, Mr. Nedelio',
#  'Petroff, Mr. Pastcho ("Pentcho")',
#  'Petterson, Mr. Johan Emil',
#  'Pettersson, Miss. Ellen Natalia',
#  'Peuchen, Major. Arthur Godfrey',
#  'Phillips, Miss. Kate Florence ("Mrs Kate Louise Phillips Marshall")',
#  'Pickard, Mr. Berk (Berk Trembisky)',
#  'Pinsky, Mrs. (Rosa)',
#  'Plotcharsky, Mr. Vasil',
#  'Ponesell, Mr. Martin',
#  'Porter, Mr. Walter Chamberlain',
#  'Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)',
#  'Quick, Miss. Phyllis May',
#  'Quick, Mrs. Frederick Charles (Jane Richards)',
#  'Radeff, Mr. Alexander',
#  'Razi, Mr. Raihed',
#  'Reed, Mr. James George',
#  'Reeves, Mr. David',
#  'Rekic, Mr. Tido',
#  'Renouf, Mr. Peter Henry',
#  'Renouf, Mrs. Peter Henry (Lillian Jefferys)',
#  'Reuchlin, Jonkheer. John George',
#  'Reynaldo, Ms. Encarnacion',
#  'Rice, Master. Arthur',
#  'Rice, Master. Eric',
#  'Rice, Master. Eugene',
#  'Rice, Master. George Hugh',
#  'Rice, Mrs. William (Margaret Norton)',
#  'Richard, Mr. Emile',
#  'Richards, Master. George Sibley',
#  'Richards, Master. William Rowe',
#  'Richards, Mrs. Sidney (Emily Hocking)',
#  'Ridsdale, Miss. Lucy',
#  'Ringhini, Mr. Sante',
#  'Rintamaki, Mr. Matti',
#  'Risien, Mr. Samuel Beard',
#  'Robbins, Mr. Victor',
#  'Robert, Mrs. Edward Scott (Elisabeth Walton McMillan)',
#  'Robins, Mrs. Alexander A (Grace Charity Laury)',
#  'Roebling, Mr. Washington Augustus II',
#  'Rogers, Mr. William John',
#  'Romaine, Mr. Charles Hallace ("Mr C Rolmane")',
#  'Rommetvedt, Mr. Knud Paust',
#  'Rood, Mr. Hugh Roscoe',
#  'Rosblom, Mr. Viktor Richard',
#  'Rosblom, Mrs. Viktor (Helena Wilhelmina)',
#  'Ross, Mr. John Hugo',
#  'Rothes, the Countess. of (Lucy Noel Martha Dyer-Edwards)',
#  'Rothschild, Mrs. Martin (Elizabeth L. Barrett)',
#  'Rouse, Mr. Richard Henry',
#  'Rugg, Miss. Emily',
#  'Rush, Mr. Alfred George John',
#  'Ryan, Mr. Patrick',
#  'Ryerson, Miss. Emily Borie',
#  'Ryerson, Miss. Susan Parker "Suzette"',
#  'Saad, Mr. Amin',
#  'Saad, Mr. Khalil',
#  'Saalfeld, Mr. Adolphe',
#  'Sadlier, Mr. Matthew',
#  'Sage, Master. Thomas Henry',
#  'Sage, Miss. Constance Gladys',
#  'Sage, Miss. Dorothy Edith "Dolly"',
#  'Sage, Miss. Stella Anna',
#  'Sage, Mr. Douglas Bullen',
#  'Sage, Mr. Frederick',
#  'Sage, Mr. George John Jr',
#  'Sagesser, Mlle. Emma',
#  'Salkjelsvik, Miss. Anna Kristine',
#  'Salonen, Mr. Johan Werner',
#  'Samaan, Mr. Youssef',
#  'Sandstrom, Miss. Marguerite Rut',
#  'Sandstrom, Mrs. Hjalmar (Agnes Charlotta Bengtsson)',
#  'Saundercock, Mr. William Henry',
#  'Sawyer, Mr. Frederick Charles',
#  'Scanlan, Mr. James',
#  'Sdycoff, Mr. Todor',
#  'Sedgwick, Mr. Charles Frederick Waddington',
#  'Serepeca, Miss. Augusta',
#  'Seward, Mr. Frederic Kimber',
#  'Sharp, Mr. Percival James R',
#  'Sheerlinck, Mr. Jan Baptist',
#  'Shellard, Mr. Frederick William',
#  'Shelley, Mrs. William (Imanita Parrish Hall)',
#  'Shorney, Mr. Charles Joseph',
#  'Shutes, Miss. Elizabeth W',
#  'Silven, Miss. Lyyli Karoliina',
#  'Silverthorne, Mr. Spencer Victor',
#  'Silvey, Mr. William Baird',
#  'Silvey, Mrs. William Baird (Alice Munger)',
#  'Simmons, Mr. John',
#  'Simonius-Blumer, Col. Oberst Alfons',
#  'Sinkkonen, Miss. Anna',
#  'Sirayanian, Mr. Orsen',
#  'Sirota, Mr. Maurice',
#  'Sivic, Mr. Husein',
#  'Sivola, Mr. Antti Wilhelm',
#  'Sjoblom, Miss. Anna Sofia',
#  'Sjostedt, Mr. Ernst Adolf',
#  'Skoog, Master. Harald',
#  'Skoog, Master. Karl Thorsten',
#  'Skoog, Miss. Mabel',
#  'Skoog, Miss. Margit Elizabeth',
#  'Skoog, Mr. Wilhelm',
#  'Skoog, Mrs. William (Anna Bernhardina Karlsson)',
#  'Slabenoff, Mr. Petco',
#  'Slayter, Miss. Hilda Mary',
#  'Slemen, Mr. Richard James',
#  'Slocovski, Mr. Selman Francis',
#  'Sloper, Mr. William Thompson',
#  'Smart, Mr. John Montgomery',
#  'Smiljanic, Mr. Mile',
#  'Smith, Miss. Marion Elsie',
#  'Smith, Mr. James Clinch',
#  'Smith, Mr. Richard William',
#  'Smith, Mr. Thomas',
#  'Sobey, Mr. Samuel James Hayden',
#  'Soholt, Mr. Peter Andreas Lauritz Andersen',
#  'Somerton, Mr. Francis William',
#  'Spedden, Mrs. Frederic Oakley (Margaretta Corning Stone)',
#  'Spencer, Mrs. William Augustus (Marie Eugenie)',
#  'Stahelin-Maeglin, Dr. Max',
#  'Staneff, Mr. Ivan',
#  'Stankovic, Mr. Ivan',
#  'Stanley, Miss. Amy Zillah Elsie',
#  'Stanley, Mr. Edward Roland',
#  'Stead, Mr. William Thomas',
#  'Stephenson, Mrs. Walter Bertram (Martha Eustis)',
#  'Stewart, Mr. Albert A',
#  'Stone, Mrs. George Nelson (Martha Evelyn)',
#  'Stoytcheff, Mr. Ilia',
#  'Strandberg, Miss. Ida Sofia',
#  'Stranden, Mr. Juho',
#  'Strom, Miss. Telma Matilda',
#  'Strom, Mrs. Wilhelm (Elna Matilda Persson)',
#  'Sunderland, Mr. Victor Francis',
#  'Sundman, Mr. Johan Julian',
#  'Sutehall, Mr. Henry Jr',
#  'Sutton, Mr. Frederick',
#  'Svensson, Mr. Johan',
#  'Svensson, Mr. Olof',
#  'Swift, Mrs. Frederick Joel (Margaret Welles Barron)',
#  'Taussig, Miss. Ruth',
#  'Taussig, Mr. Emil',
#  'Taussig, Mrs. Emil (Tillie Mandelbaum)',
#  'Taylor, Mr. Elmer Zebley',
#  'Taylor, Mrs. Elmer Zebley (Juliet Cummins Wright)',
#  'Thayer, Mr. John Borland',
#  'Thayer, Mr. John Borland Jr',
#  'Thayer, Mrs. John Borland (Marian Longstreth Morris)',
#  'Theobald, Mr. Thomas Leonard',
#  'Thomas, Master. Assad Alexander',
#  'Thorne, Mrs. Gertrude Maybelle',
#  'Thorneycroft, Mr. Percival',
#  'Thorneycroft, Mrs. Percival (Florence Kate White)',
#  'Tikkanen, Mr. Juho',
#  'Tobin, Mr. Roger',
#  'Todoroff, Mr. Lalio',
#  'Tomlin, Mr. Ernest Portage',
#  'Toomey, Miss. Ellen',
#  'Torber, Mr. Ernst William',
#  'Tornquist, Mr. William Henry',
#  'Toufik, Mr. Nakli',
#  'Touma, Mrs. Darwis (Hanne Youssef Razi)',
#  'Troupiansky, Mr. Moses Aaron',
#  'Trout, Mrs. William H (Jessie L)',
#  'Troutt, Miss. Edwina Celia "Winnie"',
#  'Turcin, Mr. Stjepan',
#  'Turja, Miss. Anna Sofia',
#  'Turkula, Mrs. (Hedwig)',
#  'Turpin, Mr. William John Robert',
#  'Turpin, Mrs. William John Robert (Dorothy Ann Wonnacott)',
#  'Uruchurtu, Don. Manuel E',
#  'Van Impe, Miss. Catharina',
#  'Van Impe, Mr. Jean Baptiste',
#  'Van Impe, Mrs. Jean Baptiste (Rosalie Paula Govaert)',
#  'Van der hoef, Mr. Wyckoff',
#  'Vande Velde, Mr. Johannes Joseph',
#  'Vande Walle, Mr. Nestor Cyriel',
#  'Vanden Steen, Mr. Leo Peter',
#  'Vander Cruyssen, Mr. Victor',
#  'Vander Planke, Miss. Augusta Maria',
#  'Vander Planke, Mr. Leo Edmondus',
#  'Vander Planke, Mrs. Julius (Emelia Maria Vandemoortele)',
#  'Vestrom, Miss. Hulda Amanda Adolfina',
#  'Vovk, Mr. Janko',
#  'Waelens, Mr. Achille',
#  'Walker, Mr. William Anderson',
#  'Ward, Miss. Anna',
#  'Warren, Mrs. Frank Manley (Anna Sophia Atkinson)',
#  'Watson, Mr. Ennis Hastings',
#  'Watt, Mrs. James (Elizabeth "Bessie" Inglis Milne)',
#  'Webber, Miss. Susan',
#  'Webber, Mr. James',
#  'Weir, Col. John',
#  'Weisz, Mrs. Leopold (Mathilde Francoise Pede)',
#  'Wells, Miss. Joan',
#  'West, Miss. Constance Mirium',
#  'West, Mr. Edwy Arthur',
#  'West, Mrs. Edwy Arthur (Ada Mary Worth)',
#  'Wheadon, Mr. Edward H',
#  'White, Mr. Percival Wayland',
#  'White, Mr. Richard Frasar',
#  'Wick, Miss. Mary Natalie',
#  'Wick, Mrs. George Dennick (Mary Hitchcock)',
#  'Widegren, Mr. Carl/Charles Peter',
#  'Widener, Mr. Harry Elkins',
#  'Wiklund, Mr. Jakob Alfred',
#  'Wilhelms, Mr. Charles',
#  'Willey, Mr. Edward',
#  'Williams, Mr. Charles Duane',
#  'Williams, Mr. Charles Eugene',
#  'Williams, Mr. Howard Hugh "Harry"',
#  'Williams, Mr. Leslie',
#  'Williams-Lambert, Mr. Fletcher Fellows',
#  'Windelov, Mr. Einar',
#  'Wiseman, Mr. Phillippe',
#  'Woolner, Mr. Hugh',
#  'Wright, Mr. George',
#  'Yasbeck, Mr. Antoni',
#  'Yasbeck, Mrs. Antoni (Selini Alexander)',
#  'Young, Miss. Marie Grice',
#  'Youseff, Mr. Gerious',
#  'Yousif, Mr. Wazli',
#  'Yousseff, Mr. Gerious',
#  'Yrois, Miss. Henriette ("Mrs Harbeck")',
#  'Zabour, Miss. Hileni',
#  'Zabour, Miss. Thamine',
#  'Zimmerman, Mr. Leo',
#  'de Messemaeker, Mrs. Guillaume Joseph (Emma)',
#  'de Mulder, Mr. Theodore',
#  'de Pelsmaeker, Mr. Alfons',
#  'del Carlo, Mr. Sebastiano',
#  'van Billiard, Mr. Austin Blyler',
#  'van Melkebeke, Mr. Philemon'}

# %%
###Create new column Title
import seaborn as sns
import pandas as pand
import numpy as np
import matplotlib.pyplot as plt
df = pand.read_csv("titanic.csv")
print("Create column Title result ")

try:  
    Title = np.array([df["Name"][i][ df["Name"][i].index(",")+2 :df["Name"][i].index(".")].split(' ') for i in df.index])
       ##for dataset in df: => c'est une autre façon de faire l'extraction de Regex
       ## dataset['Title'] = dataset.Name.str.extract(' ([A-Za-z]+)\.', expand = False)
       ##pand.crosstab(df['Title'], df['Sex'])
    
     
    for i in range(len(df)):
        df['Title']=Title
        df=df.replace({"Title": Title_Dic})
        df["Cabin"].fillna("C"+str(random.randint(1,1461)),inplace=True)
        dfnew= df.to_csv('new.csv')
      
except AttributeError:
    pass
    
dfs = pand.read_csv("new.csv")    
sns.violinplot(data = dfs.head(100), x = 'Title', y = 'Survived')
# Out:
# Create column Title result
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:10: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   # Remove the CWD from sys.path while we load stuff.

# %%
df['Title']
# Out:
# 0        [Mr]
# 1       [Mrs]
# 2      [Miss]
# 3       [Mrs]
# 4        [Mr]
#         ...
# 886     [Rev]
# 887    [Miss]
# 888    [Miss]
# 889      [Mr]
# 890      [Mr]
# Name: Title, Length: 891, dtype: object

# %%
print(df[['SibSp', 'Survived']].groupby(['SibSp']).mean())
print('\n\n')
print(df[['Parch', 'Survived']].groupby(['Parch']).mean())
print(df.shape)
# Out:
#        Survived
# SibSp
# 0      0.345395
# 1      0.535885
# 2      0.464286
# 3      0.250000
# 4      0.166667
# 5      0.000000
# 8      0.000000
#
#
#
#        Survived
# Parch
# 0      0.343658
# 1      0.550847
# 2      0.500000
# 3      0.600000
# 4      0.000000
# 5      0.200000
# 6      0.000000
# (891, 13)

# %%
df
# Out:
#      PassengerId  Survived  Pclass  ... Cabin Embarked   Title
# 0              1         0       3  ...   NaN        S    [Mr]
# 1              2         1       1  ...   C85        C   [Mrs]
# 2              3         1       3  ...   NaN        S  [Miss]
# 3              4         1       1  ...  C123        S   [Mrs]
# 4              5         0       3  ...   NaN        S    [Mr]
# ..           ...       ...     ...  ...   ...      ...     ...
# 886          887         0       2  ...   NaN        S   [Rev]
# 887          888         1       1  ...   B42        S  [Miss]
# 888          889         0       3  ...   NaN        S  [Miss]
# 889          890         1       1  ...  C148        C    [Mr]
# 890          891         0       3  ...   NaN        Q    [Mr]
#
# [891 rows x 13 columns]

# %% [markdown]
# **Family Size Feature:**

# %%
df[["SibSp", "Survived"]].groupby(['SibSp'], as_index=False).mean().sort_values(by='Survived', ascending=False)
# Out:
#    SibSp  Survived
# 1      1  0.535885
# 2      2  0.464286
# 0      0  0.345395
# 3      3  0.250000
# 4      4  0.166667
# 5      5  0.000000
# 6      8  0.000000

# %%
df[["Parch", "Survived"]].groupby(['Parch'], as_index=False).mean().sort_values(by='Survived', ascending=False)
# Out:
#    Parch  Survived
# 3      3  0.600000
# 1      1  0.550847
# 2      2  0.500000
# 0      0  0.343658
# 5      5  0.200000
# 4      4  0.000000
# 6      6  0.000000

# %% [markdown]
# Deduction: calculation percentage of survived people using their parch id and sibling sibSp id is not very precise measure to use while analysing who survived we should calculate survived classes.
# Because when the accident happened in 1912 there's people of the first class, second class and poor people in the third class and then others workers in the 4,5 and 6.
# So analysing such event needs coherent variables.

# %%
import numpy as np
import pandas as pand
import matplotlib.pyplot as plt
df = pand.read_csv("new.csv")
df['FamilySize']=df["Parch"]+df["SibSp"]
df.head(150)
# Out:
#      Unnamed: 0  PassengerId  Survived  ...  Embarked     Title FamilySize
# 0             0            1         0  ...         S    ['Mr']          1
# 1             1            2         1  ...         C   ['Mrs']          1
# 2             2            3         1  ...         S  ['Miss']          0
# 3             3            4         1  ...         S   ['Mrs']          1
# 4             4            5         0  ...         S    ['Mr']          0
# ..          ...          ...       ...  ...       ...       ...        ...
# 145         145          146         0  ...         S    ['Mr']          2
# 146         146          147         1  ...         S    ['Mr']          0
# 147         147          148         0  ...         S  ['Miss']          4
# 148         148          149         0  ...         S    ['Mr']          2
# 149         149          150         0  ...         S   ['Rev']          0
#
# [150 rows x 15 columns]

# %%
df[["FamilySize", "Survived"]].groupby(['FamilySize'], as_index=False).mean().sort_values(by='FamilySize', ascending=True)
# Out:
#    FamilySize  Survived
# 0           0  0.303538
# 1           1  0.552795
# 2           2  0.578431
# 3           3  0.724138
# 4           4  0.200000
# 5           5  0.136364
# 6           6  0.333333
# 7           7  0.000000
# 8          10  0.000000

# %%
df[["Title", "Survived"]].groupby(['Title'], as_index=False).mean().sort_values(by='Survived', ascending=True)
# Out:
# ---------------------------------------------------------------------------
# DataError                                 Traceback (most recent call last)
# <ipython-input-80-84ac7c988935> in <module>()
# ----> 1 df[["Title", "Survived"]].groupby(['Title'], as_index=False).mean().sort_values(by='Survived', ascending=True)
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/groupby/groupby.py in mean(self, numeric_only)
#    1396             "mean",
#    1397             alt=lambda x, axis: Series(x).mean(numeric_only=numeric_only),
# -> 1398             numeric_only=numeric_only,
#    1399         )
#    1400
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/groupby/generic.py in _cython_agg_general(self, how, alt, numeric_only, min_count)
#    1020     ) -> DataFrame:
#    1021         agg_blocks, agg_items = self._cython_agg_blocks(
# -> 1022             how, alt=alt, numeric_only=numeric_only, min_count=min_count
#    1023         )
#    1024         return self._wrap_agged_blocks(agg_blocks, items=agg_items)
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/groupby/generic.py in _cython_agg_blocks(self, how, alt, numeric_only, min_count)
#    1128
#    1129         if not (agg_blocks or split_frames):
# -> 1130             raise DataError("No numeric types to aggregate")
#    1131
#    1132         if split_items:
#
# DataError: No numeric types to aggregate

# %% [markdown]
# It's obvious that this rescue method is not very performant.
# There're 30% of survived crew who have no family member on board.
# people with familysize up to 4 have a few chance to survive.
